# %% [markdown]
# # Waterbomb cell - 5 parameter folding

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy as sp
sp.init_printing()
import numpy as np

# %% [markdown]
# ## Upper right corner node

# %% [markdown]
# Control parameters $a, b, c$ and angle $\alpha$

# %%
a, b, c = sp.symbols('a, b, c', positive=True)
gamma = sp.symbols('gamma', positive=True)

# %% [markdown]
# Position variables to be determined for the above control parameters

# %%
U_ur_0 = sp.Matrix([a, b, 0])
U_ul_0 = sp.Matrix([-a, b, 0])
V_r_0 = sp.Matrix([c, 0, 0])
V_l_0 = sp.Matrix([-c, 0, 0])
U_ul_0, V_l_0, U_ur_0, V_r_0
# Out:
# ⎛⎡-a⎤  ⎡-c⎤  ⎡a⎤  ⎡c⎤⎞
# ⎜⎢  ⎥  ⎢  ⎥  ⎢ ⎥  ⎢ ⎥⎟
# ⎜⎢b ⎥, ⎢0 ⎥, ⎢b⎥, ⎢0⎥⎟
# ⎜⎢  ⎥  ⎢  ⎥  ⎢ ⎥  ⎢ ⎥⎟
# ⎝⎣0 ⎦  ⎣0 ⎦  ⎣0⎦  ⎣0⎦⎠

# %% [markdown]
# # Solution based on constant sector angles

# %%
u_ur, v_ur, w_ur = sp.symbols(r'u^{\urcorner}, v^{\urcorner}, w^{\urcorner}')
u_ul, v_ul, w_ul = sp.symbols(r'u^{\ulcorner}, v^{\ulcorner}, w^{\ulcorner}')

# %% [markdown]
# Node $V^\dashv$ rotates in the $xz$ plane. The control angle $\gamma = \pi/2$ for a flat state, i.e. $z^\dashv(\gamma=\pi/2) = 0$
# \begin{align}
#  V^\dashv = [c \sin(\gamma), 0, c \cos(\gamma)]
# \end{align}

# %%
U_ur_1 = U_ur_0 + sp.Matrix([u_ur, v_ur, w_ur])
U_ul_1 = U_ul_0 + sp.Matrix([u_ul, v_ul, w_ul])
U_ur_1, U_ul_1
# Out:
# ⎛⎡a + u__{\urcorner}⎤  ⎡-a + u__{\ulcorner}⎤⎞
# ⎜⎢                  ⎥  ⎢                   ⎥⎟
# ⎜⎢b + v__{\urcorner}⎥, ⎢b + v__{\ulcorner} ⎥⎟
# ⎜⎢                  ⎥  ⎢                   ⎥⎟
# ⎝⎣  w__{\urcorner}  ⎦  ⎣  w__{\ulcorner}   ⎦⎠

# %%
V_r_1 = V_r_0 + sp.Matrix([c * sp.sin(gamma), 0, c * sp.cos(gamma)])
V_l_1 = V_l_0 + sp.Matrix([-c * sp.sin(gamma), 0, c * sp.cos(gamma)])
V_r_1, V_l_1
# Out:
# ⎛⎡c⋅sin(γ) + c⎤  ⎡-c⋅sin(γ) - c⎤⎞
# ⎜⎢            ⎥  ⎢             ⎥⎟
# ⎜⎢     0      ⎥, ⎢      0      ⎥⎟
# ⎜⎢            ⎥  ⎢             ⎥⎟
# ⎝⎣  c⋅cos(γ)  ⎦  ⎣  c⋅cos(γ)   ⎦⎠

# %% [markdown]
# Positions of $U^\urcorner_0$ and $V^\dashv_0$

# %% [markdown]
# ## Scalar products $OU^\urcorner \cdot OV^\dashv$ and $OU^\ulcorner \cdot OV^\vdash$

# %%
X_UOV_r_0 = U_ur_0.T * V_r_0
X_VOU_l_0 = U_ul_0.T * V_l_0
X_UOV_r_0, X_VOU_l_0
# Out:
# ([a⋅c], [a⋅c])

# %%
X_UOV_r_1 = U_ur_1.T * V_r_1
X_VOU_l_1 = U_ul_1.T * V_l_1
X_UOV_r_1, X_VOU_l_1
# Out:
# ([c⋅w__{\urcorner}⋅cos(γ) + (a + u__{\urcorner})⋅(c⋅sin(γ) + c)], [c⋅w__{\ulco
# rner}⋅cos(γ) + (-a + u__{\ulcorner})⋅(-c⋅sin(γ) - c)])

# %%
Eq_UOV_r = sp.Eq( X_UOV_r_0[0], X_UOV_r_1[0])
Eq_UOV_l = sp.Eq( X_VOU_l_0[0], X_VOU_l_1[0])
Eq_UOV_r, Eq_UOV_l
# Out:
# (a⋅c = c⋅w__{\urcorner}⋅cos(γ) + (a + u__{\urcorner})⋅(c⋅sin(γ) + c), a⋅c = c⋅
# w__{\ulcorner}⋅cos(γ) + (-a + u__{\ulcorner})⋅(-c⋅sin(γ) - c))

# %% [markdown]
# ## Scalar product  $U^\urcorner V^\dashv \cdot U^{\urcorner}O$ and $U^\ulcorner V^\vdash \cdot U^{\ulcorner}O$

# %%
X_VUO_r_0 = (V_r_0 - U_ur_0).T * (-U_ur_0)
X_VUO_l_0 = (V_l_0 - U_ul_0).T * (-U_ul_0)
X_VUO_r_0, X_VUO_l_0
# Out:
# ⎛⎡               2⎤  ⎡             2⎤⎞
# ⎝⎣-a⋅(-a + c) + b ⎦, ⎣a⋅(a - c) + b ⎦⎠

# %%
X_VUO_r_1 = (V_r_1 - U_ur_1).T * (-U_ur_1)
X_VUO_l_1 = (V_l_1 - U_ul_1).T * (-U_ul_1)
X_VUO_r_1, X_VUO_l_1
# Out:
# ⎛⎡
# ⎝⎣-w__{\urcorner}⋅(c⋅cos(γ) - w__{\urcorner}) + (-a - u__{\urcorner})⋅(-a + c⋅
#
#                                                     2⎤  ⎡
# sin(γ) + c - u__{\urcorner}) + (-b - v__{\urcorner}) ⎦, ⎣-w__{\ulcorner}⋅(c⋅co
#
#
# s(γ) - w__{\ulcorner}) + (a - u__{\ulcorner})⋅(a - c⋅sin(γ) - c - u__{\ulcorne
#
#                            2⎤⎞
# r}) + (-b - v__{\ulcorner}) ⎦⎠

# %%
Eq_VUO_r = sp.Eq( -X_VUO_r_0[0], -X_VUO_r_1[0])
Eq_VUO_l = sp.Eq( -X_VUO_l_0[0], -X_VUO_l_1[0])
Eq_VUO_r, Eq_VUO_l
# Out:
# ⎛              2
# ⎝a⋅(-a + c) - b  = w__{\urcorner}⋅(c⋅cos(γ) - w__{\urcorner}) - (-a - u__{\urc
#
#                                                                     2
# orner})⋅(-a + c⋅sin(γ) + c - u__{\urcorner}) - (-b - v__{\urcorner}) , -a⋅(a -
#
#        2
#  c) - b  = w__{\ulcorner}⋅(c⋅cos(γ) - w__{\ulcorner}) - (a - u__{\ulcorner})⋅(
#
#                                                           2⎞
# a - c⋅sin(γ) - c - u__{\ulcorner}) - (-b - v__{\ulcorner}) ⎠

# %% [markdown]
# ## Scalar product between $OU^\ulcorner$ and $OU^\urcorner$

# %%
X_UOU_0 = (U_ul_0).T * (U_ur_0)
X_UOU_0
# Out:
# ⎡   2    2⎤
# ⎣- a  + b ⎦

# %%
X_UOU_1 = (U_ul_1).T * (U_ur_1)
X_UOU_1
# Out:
# [w__{\ulcorner}⋅w__{\urcorner} + (-a + u__{\ulcorner})⋅(a + u__{\urcorner}) +
# (b + v__{\ulcorner})⋅(b + v__{\urcorner})]

# %%
Eq_UOU = sp.Eq(X_UOU_0[0], X_UOU_1[0])
Eq_UOU
# Out:
#    2    2
# - a  + b  = w__{\ulcorner}⋅w__{\urcorner} + (-a + u__{\ulcorner})⋅(a + u__{\ur
#
#
# corner}) + (b + v__{\ulcorner})⋅(b + v__{\urcorner})

# %% [markdown]
# # Length of $U^\ulcorner U^\urcorner$

# %%
L2_UU_u_0 = ((U_ur_0 - U_ul_0).T * (U_ur_0 - U_ul_0))[0]
L2_UU_u_0
# Out:
#    2
# 4⋅a

# %%
L2_UU_u_1 = ((U_ur_1 - U_ul_1).T * (U_ur_1 - U_ul_1))[0]
L2_UU_u_1
# Out:
#                                   2                                     2
# (-v__{\ulcorner} + v__{\urcorner})  + (-w__{\ulcorner} + w__{\urcorner})  + (2
#
#                                      2
# ⋅a - u__{\ulcorner} + u__{\urcorner})

# %%
Eq_L2_UU_u = sp.Eq(L2_UU_u_0, L2_UU_u_1)
Eq_L2_UU_u
# Out:
#    2                                     2
# 4⋅a  = (-v__{\ulcorner} + v__{\urcorner})  + (-w__{\ulcorner} + w__{\urcorner}
#
#  2                                          2
# )  + (2⋅a - u__{\ulcorner} + u__{\urcorner})

# %%
u_ul_sol = sp.solve(Eq_L2_UU_u, u_ul)[0]
u_ul_sol
# Out:
#                           ____________________________________________________
#                          ╱    2                 2
# 2⋅a + u__{\urcorner} - ╲╱  4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\urco
#
# ______________________________________________________________________________
#                       2                 2
# rner} - v__{\urcorner}  - w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner} -
#
# ________________
#               2
# w__{\urcorner}

# %%
u_u = sp.symbols(r'u^\top')
Eq_u_u_ = sp.Eq( u_u, sp.Rational(1,2) * (u_ur + u_ul))
u_ur_subs = sp.solve(Eq_u_u_, u_ur)[0]
u_ul_subs = sp.solve(Eq_u_u_, u_ul)[0]
u_ur_subs, u_ul_subs
# Out:
# (2⋅u__\top - u__{\ulcorner}, 2⋅u__\top - u__{\urcorner})

# %%
subs_u_ul_sol = u_ul_sol.subs(u_ur, u_ur_subs)
u_ul_sol_u = sp.solve(sp.Eq(u_ul, subs_u_ul_sol), u_ul)[0]
u_ul_sol_u
# Out:
#                  _____________________________________________________________
#                 ╱    2                 2
#               ╲╱  4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\urcorner} - v
# a + u__\top - ────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#              2                 2
# __{\urcorner}  - w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner} - w__{\urco
# ──────────────────────────────────────────────────────────────────────────────
#           2
#
# _______
#      2
# rner}
# ───────

# %%
Eq_UOU_u = Eq_UOU.subs(u_ul, u_ul_sol_u)
Eq_UOU_u
# Out:
#                                                                  ⎛
#                                                                  ⎜
#    2    2                                                        ⎜          ╲╱
# - a  + b  = w__{\ulcorner}⋅w__{\urcorner} + (a + u__{\urcorner})⋅⎜u__\top - ──
#                                                                  ⎝
#
#  _____________________________________________________________________________
# ╱    2                 2                                                   2
#   4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\urcorner} - v__{\urcorner}  -
# ──────────────────────────────────────────────────────────────────────────────
#                                                                         2
#
# _____________________________________________________________________⎞
#                2                                                   2 ⎟
#  w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner} - w__{\urcorner}  ⎟
# ─────────────────────────────────────────────────────────────────────⎟ + (b +
#                                                                      ⎠
#
#
#
#
# v__{\ulcorner})⋅(b + v__{\urcorner})

# %%
u_ur_sol = sp.solve(Eq_UOU_u, u_ur)[0]
u_ur_sol
# Out:
#                             __________________________________________________
#      2                     ╱    2                 2
# - 2⋅a  - 2⋅a⋅u__\top + a⋅╲╱  4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\ur
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             __
#                                                                            ╱
#                                                              2⋅u__\top - ╲╱  4
#
# ______________________________________________________________________________
#                         2                 2
# corner} - v__{\urcorner}  - w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner}
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#   2                 2                                                   2
# ⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\urcorner} - v__{\urcorner}  - w_
#
# __________________
#                 2
# - w__{\urcorner}   - 2⋅b⋅v__{\ulcorner} - 2⋅b⋅v__{\urcorner} - 2⋅v__{\ulcorner
# ──────────────────────────────────────────────────────────────────────────────
# __________________________________________________________________
#             2                                                   2
# _{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner} - w__{\urcorner}
#
#
#
# }⋅v__{\urcorner} - 2⋅w__{\ulcorner}⋅w__{\urcorner}
# ──────────────────────────────────────────────────

# %%
u_ul_subs.subs(u_ur, u_ur_sol)
# Out:
#                                         ______________________________________
#                  2                     ╱    2                 2
#             - 2⋅a  - 2⋅a⋅u__\top + a⋅╲╱  4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcor
# 2⋅u__\top - ──────────────────────────────────────────────────────────────────
#
#
#                                                                          2⋅u__
#
# ______________________________________________________________________________
#                                     2                 2
# ner}⋅v__{\urcorner} - v__{\urcorner}  - w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__
# ──────────────────────────────────────────────────────────────────────────────
#           ____________________________________________________________________
#          ╱    2                 2
# \top - ╲╱  4⋅a  - v__{\ulcorner}  + 2⋅v__{\ulcorner}⋅v__{\urcorner} - v__{\urc
#
# ______________________________
#                             2
# {\urcorner} - w__{\urcorner}   - 2⋅b⋅v__{\ulcorner} - 2⋅b⋅v__{\urcorner} - 2⋅v
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#       2                 2                                                   2
# orner}  - w__{\ulcorner}  + 2⋅w__{\ulcorner}⋅w__{\urcorner} - w__{\urcorner}
#
#
#
# __{\ulcorner}⋅v__{\urcorner} - 2⋅w__{\ulcorner}⋅w__{\urcorner}
# ──────────────────────────────────────────────────────────────

# %%
uw_ur_sol1, uw_ur_sol2 = sp.solve({Eq_UOV_r, Eq_VUO_r}, [u_ur, w_ur])

# %%
u_ur_sol, w_ur_sol = uw_ur_sol1

# %%
u_ur_sol
# Out:
#                    ___________________________________________________________
#                   ╱    2           2
# -a⋅sin(γ) - a + ╲╱  2⋅a ⋅sin(γ) + a  - 4⋅b⋅v__{\urcorner}⋅sin(γ) - 4⋅b⋅v__{\ur
# ──────────────────────────────────────────────────────────────────────────────
#                                                                2⋅(sin(γ) + 1)
#
# _______________________________________________________
#                           2                          2
# corner} - 2⋅v__{\urcorner} ⋅sin(γ) - 2⋅v__{\urcorner}  ⋅cos(γ)
# ──────────────────────────────────────────────────────────────

# %% [markdown]
# ## Solve for $U^\urcorner(x^\urcorner)$ and $U^\ulcorner(x^\ulcorner)$

# %%
vw_ur_sol1, vw_ur_sol2 = sp.solve({Eq_UOV_r, Eq_VUO_r}, [v_ur, w_ur])
vw_ul_sol1, vw_ul_sol2 = sp.solve({Eq_UOV_l, Eq_VUO_l}, [v_ul, w_ul])

# %%
v_ur_sol1, w_ur_sol1 = vw_ur_sol1
v_ul_sol1, w_ul_sol1 = vw_ul_sol1
v_ur_sol2, w_ur_sol2 = vw_ur_sol2
v_ul_sol2, w_ul_sol2 = vw_ul_sol2

# %%
w_ur_sol1, w_ul_sol1
# Out:
# ⎛-(a⋅sin(γ) + u__{\urcorner}⋅sin(γ) + u__{\urcorner})   -a⋅sin(γ) + u__{\ulcor
# ⎜─────────────────────────────────────────────────────, ──────────────────────
# ⎝                        cos(γ)
#
# ner}⋅sin(γ) + u__{\ulcorner}⎞
# ────────────────────────────⎟
# cos(γ)                      ⎠

# %%
w_ur_sol2, w_ul_sol2
# Out:
# ⎛-(a⋅sin(γ) + u__{\urcorner}⋅sin(γ) + u__{\urcorner})   -a⋅sin(γ) + u__{\ulcor
# ⎜─────────────────────────────────────────────────────, ──────────────────────
# ⎝                        cos(γ)
#
# ner}⋅sin(γ) + u__{\ulcorner}⎞
# ────────────────────────────⎟
# cos(γ)                      ⎠

# %%
v_ur_sol1, v_ul_sol1
# Out:
# ⎛        _____________________________________________________________________
# ⎜       ╱    2    2                                                        2
# ⎜     ╲╱  - a ⋅sin (γ) - 2⋅a⋅u__{\urcorner}⋅sin(γ) - 2⋅a⋅u__{\urcorner} - b ⋅s
# ⎜-b - ────────────────────────────────────────────────────────────────────────
# ⎝                                                                    cos(γ)
#
# ___________________________________________________________          _________
#   2       2                   2                          2          ╱    2
# in (γ) + b  - 2⋅u__{\urcorner} ⋅sin(γ) - 2⋅u__{\urcorner}         ╲╱  - a ⋅sin
# ───────────────────────────────────────────────────────────, -b - ────────────
#
#
# ______________________________________________________________________________
# 2                                                        2    2       2
#  (γ) + 2⋅a⋅u__{\ulcorner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b ⋅sin (γ) + b  - 2⋅u_
# ──────────────────────────────────────────────────────────────────────────────
#                                                    cos(γ)
#
# _________________________________________⎞
#             2                          2 ⎟
# _{\ulcorner} ⋅sin(γ) - 2⋅u__{\ulcorner}  ⎟
# ─────────────────────────────────────────⎟
#                                          ⎠

# %%
v_ur_sol2, v_ul_sol2
# Out:
# ⎛        _____________________________________________________________________
# ⎜       ╱    2    2                                                        2
# ⎜     ╲╱  - a ⋅sin (γ) - 2⋅a⋅u__{\urcorner}⋅sin(γ) - 2⋅a⋅u__{\urcorner} - b ⋅s
# ⎜-b + ────────────────────────────────────────────────────────────────────────
# ⎝                                                                    cos(γ)
#
# ___________________________________________________________          _________
#   2       2                   2                          2          ╱    2
# in (γ) + b  - 2⋅u__{\urcorner} ⋅sin(γ) - 2⋅u__{\urcorner}         ╲╱  - a ⋅sin
# ───────────────────────────────────────────────────────────, -b + ────────────
#
#
# ______________________________________________________________________________
# 2                                                        2    2       2
#  (γ) + 2⋅a⋅u__{\ulcorner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b ⋅sin (γ) + b  - 2⋅u_
# ──────────────────────────────────────────────────────────────────────────────
#                                                    cos(γ)
#
# _________________________________________⎞
#             2                          2 ⎟
# _{\ulcorner} ⋅sin(γ) - 2⋅u__{\ulcorner}  ⎟
# ─────────────────────────────────────────⎟
#                                          ⎠

# %%
subs_vw1 = {v_ur:v_ur_sol1, w_ur:w_ur_sol1,
            v_ul:v_ul_sol1, w_ul:w_ul_sol1}
subs_vw2 = {v_ur:v_ur_sol2, w_ur:w_ur_sol2,
            v_ul:v_ul_sol2, w_ul:w_ul_sol2}

# %% [markdown]
# ### Solutions $U^\urcorner(x^\urcorner)$ and $U^\ulcorner(x^\ulcorner)$

# %%
Eq_UOU_x1 = Eq_UOU.subs(subs_vw1)
Eq_UOU_x2 = Eq_UOU.subs(subs_vw2)
Eq_UOU_x1, Eq_UOU_x2
# Out:
# ⎛
# ⎜
# ⎜   2    2                                                (-a⋅sin(γ) + u__{\ul
# ⎜- a  + b  = (-a + u__{\ulcorner})⋅(a + u__{\urcorner}) - ────────────────────
# ⎜
# ⎝
#
#
#
# corner}⋅sin(γ) + u__{\ulcorner})⋅(a⋅sin(γ) + u__{\urcorner}⋅sin(γ) + u__{\urco
# ──────────────────────────────────────────────────────────────────────────────
#                                2
#                             cos (γ)
#
#             __________________________________________________________________
#            ╱    2    2
# rner})   ╲╱  - a ⋅sin (γ) + 2⋅a⋅u__{\ulcorner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b
# ────── + ─────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________    ____________
# 2    2       2                   2                          2    ╱    2    2
#  ⋅sin (γ) + b  - 2⋅u__{\ulcorner} ⋅sin(γ) - 2⋅u__{\ulcorner}  ⋅╲╱  - a ⋅sin (γ
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2
#                                                            cos (γ)
#
# ______________________________________________________________________________
#                                                       2    2       2
# ) - 2⋅a⋅u__{\urcorner}⋅sin(γ) - 2⋅a⋅u__{\urcorner} - b ⋅sin (γ) + b  - 2⋅u__{\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________
#          2                          2
# urcorner} ⋅sin(γ) - 2⋅u__{\urcorner}       2    2
# ──────────────────────────────────────, - a  + b  = (-a + u__{\ulcorner})⋅(a +
#
#
#
#
#
#                    (-a⋅sin(γ) + u__{\ulcorner}⋅sin(γ) + u__{\ulcorner})⋅(a⋅sin
#  u__{\urcorner}) - ───────────────────────────────────────────────────────────
#                                                                       2
#                                                                    cos (γ)
#
#                                                    ___________________________
#                                                   ╱    2    2
# (γ) + u__{\urcorner}⋅sin(γ) + u__{\urcorner})   ╲╱  - a ⋅sin (γ) + 2⋅a⋅u__{\ul
# ───────────────────────────────────────────── + ──────────────────────────────
#
#
#
# ______________________________________________________________________________
#                                        2    2       2                   2
# corner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b ⋅sin (γ) + b  - 2⋅u__{\ulcorner} ⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _______________________    ___________________________________________________
#                      2    ╱    2    2
# γ) - 2⋅u__{\ulcorner}  ⋅╲╱  - a ⋅sin (γ) - 2⋅a⋅u__{\urcorner}⋅sin(γ) - 2⋅a⋅u__
# ──────────────────────────────────────────────────────────────────────────────
#                        2
#                     cos (γ)
#
# _____________________________________________________________________________⎞
#                2    2       2                   2                          2 ⎟
# {\urcorner} - b ⋅sin (γ) + b  - 2⋅u__{\urcorner} ⋅sin(γ) - 2⋅u__{\urcorner}  ⎟
# ─────────────────────────────────────────────────────────────────────────────⎟
#                                                                              ⎟
#                                                                              ⎠

# %% [markdown]
# This equation has a form
# \begin{align}
# C = x + \sqrt{Ax} + Bx
# \end{align}
# To get rid of the square root let it rearranged to
# \begin{align}
# -\sqrt{Ax}  = -C + x + Bx
# \end{align}
# to obtain

# %%
Eq_UOU_x_rearr1 = sp.Eq( -Eq_UOU_x1.args[1].args[1], -Eq_UOU_x1.args[0] + Eq_UOU_x1.args[1].args[0] + Eq_UOU_x1.args[1].args[2] )
Eq_UOU_x_rearr2 = sp.Eq( -Eq_UOU_x2.args[1].args[1], -Eq_UOU_x2.args[0] + Eq_UOU_x2.args[1].args[0] + Eq_UOU_x2.args[1].args[2] )
sp.trigsimp(Eq_UOU_x_rearr2)
# Out:
#     __________________________________________________________________________
#    ╱    2    2                                                        2    2
# -╲╱  - a ⋅sin (γ) + 2⋅a⋅u__{\ulcorner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b ⋅sin (γ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________    ____________________
#      2                   2                          2    ╱    2    2
# ) + b  - 2⋅u__{\ulcorner} ⋅sin(γ) - 2⋅u__{\ulcorner}  ⋅╲╱  - a ⋅sin (γ) - 2⋅a⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                       2
#                                                    cos (γ)
#
# ______________________________________________________________________________
#                                               2    2       2
# u__{\urcorner}⋅sin(γ) - 2⋅a⋅u__{\urcorner} - b ⋅sin (γ) + b  - 2⋅u__{\urcorner
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________
#  2                          2
# } ⋅sin(γ) - 2⋅u__{\urcorner}       2    2
# ─────────────────────────────── = a  - b  + (-a + u__{\ulcorner})⋅(a + u__{\ur
#
#
#
#
#
#            (-a⋅sin(γ) + u__{\ulcorner}⋅sin(γ) + u__{\ulcorner})⋅(a⋅sin(γ) + u_
# corner}) - ───────────────────────────────────────────────────────────────────
#                                                               2
#                                                            cos (γ)
#
#
#
# _{\urcorner}⋅sin(γ) + u__{\urcorner})
# ─────────────────────────────────────

# %% [markdown]
# The square of the left and right hand side renders
# \begin{align}
# -Ax = (-C + x + Bx)^2 \implies (-C + x + Bx)^2+Ax = 0.
# \end{align}
# After expanding the terms in the squared paranthesis and collecting terms associated to the individual powers of $x$
# we obtain a quadratic equation for $x^\ulcorner$

# %%
Eq_UOU_x_rhs = Eq_UOU_x_rearr2.args[1]**2 - Eq_UOU_x_rearr2.args[0]**2
Eq_UOU_x_rhs_collect = sp.collect( sp.expand(Eq_UOU_x_rhs), u_ul )
Eq_UOU_x_rhs_collect
# Out:
#    3                   4         3                   2         3
# 2⋅a ⋅u__{\urcorner}⋅sin (γ)   2⋅a ⋅u__{\urcorner}⋅sin (γ)   2⋅a ⋅u__{\urcorner
# ─────────────────────────── - ─────────────────────────── - ──────────────────
#              4                             2                             4
#           cos (γ)                       cos (γ)                       cos (γ)
#
#      2         2  2    4         2  2    2         2  2    2       2
# }⋅sin (γ)   2⋅a ⋅b ⋅sin (γ)   2⋅a ⋅b ⋅sin (γ)   2⋅a ⋅b ⋅sin (γ)   a ⋅u__{\urco
# ───────── - ─────────────── - ─────────────── + ─────────────── + ────────────
#                    4                 2                 4
#                 cos (γ)           cos (γ)           cos (γ)                cos
#
#      2    4         2               2    2       2               2    2
# rner} ⋅sin (γ)   2⋅a ⋅u__{\urcorner} ⋅sin (γ)   a ⋅u__{\urcorner} ⋅sin (γ)   2
# ────────────── - ──────────────────────────── - ────────────────────────── - ─
# 4                             2                             4
#  (γ)                       cos (γ)                       cos (γ)
#
#   2               2                                    2                   3
# ⋅a ⋅u__{\urcorner} ⋅sin(γ)    2               2   2⋅a⋅b ⋅u__{\urcorner}⋅sin (γ
# ────────────────────────── + a ⋅u__{\urcorner}  - ────────────────────────────
#             2                                                   4
#          cos (γ)                                             cos (γ)
#
#          2                   2           2                   2           2
# )   2⋅a⋅b ⋅u__{\urcorner}⋅sin (γ)   2⋅a⋅b ⋅u__{\urcorner}⋅sin (γ)   2⋅a⋅b ⋅u__
# ─ - ───────────────────────────── - ───────────────────────────── - ──────────
#                   2                               4
#                cos (γ)                         cos (γ)
#
#                           2
# {\urcorner}⋅sin(γ)   2⋅a⋅b ⋅u__{\urcorner}⋅sin(γ)        2                  2⋅
# ────────────────── + ──────────────────────────── + 2⋅a⋅b ⋅u__{\urcorner} + ──
#    2                              4
# cos (γ)                        cos (γ)
#
#    2                   4    4         4    2               4        2
# a⋅b ⋅u__{\urcorner}   b ⋅sin (γ)   2⋅b ⋅sin (γ)    4      b      2⋅b ⋅u__{\urc
# ─────────────────── - ────────── + ──────────── + b  - ─────── - ─────────────
#         4                 4             4                 4
#      cos (γ)           cos (γ)       cos (γ)           cos (γ)             cos
#
#       2    3         2               2    2         2               2
# orner} ⋅sin (γ)   2⋅b ⋅u__{\urcorner} ⋅sin (γ)   2⋅b ⋅u__{\urcorner} ⋅sin(γ)
# ─────────────── - ──────────────────────────── + ─────────────────────────── +
# 4                              4                              4
#  (γ)                        cos (γ)                        cos (γ)
#
#     2               2                   ⎛ 2    4         2    2       2    2
#  2⋅b ⋅u__{\urcorner}                  2 ⎜a ⋅sin (γ)   2⋅a ⋅sin (γ)   a ⋅sin (γ
#  ──────────────────── + u__{\ulcorner} ⋅⎜────────── - ──────────── - ─────────
#           4                             ⎜    4             2             4
#        cos (γ)                          ⎝ cos (γ)       cos (γ)       cos (γ)
#
#        2                                     4                            3
# )   2⋅a ⋅sin(γ)    2   2⋅a⋅u__{\urcorner}⋅sin (γ)   6⋅a⋅u__{\urcorner}⋅sin (γ)
# ─ - ─────────── + a  + ────────────────────────── + ──────────────────────────
#          2                         4                            4
#       cos (γ)                   cos (γ)                      cos (γ)
#
#                          2                            2
#    4⋅a⋅u__{\urcorner}⋅sin (γ)   2⋅a⋅u__{\urcorner}⋅sin (γ)   6⋅a⋅u__{\urcorner
#  - ────────────────────────── + ────────────────────────── - ─────────────────
#                2                            4                            2
#             cos (γ)                      cos (γ)                      cos (γ)
#
#
# }⋅sin(γ)   6⋅a⋅u__{\urcorner}⋅sin(γ)                        2⋅a⋅u__{\urcorner}
# ──────── - ───────────────────────── + 2⋅a⋅u__{\urcorner} - ──────────────────
#                        4                                            2
#                     cos (γ)                                      cos (γ)
#
#                            2    3         2    2         2               2
#    4⋅a⋅u__{\urcorner}   2⋅b ⋅sin (γ)   2⋅b ⋅sin (γ)   2⋅b ⋅sin(γ)     2⋅b
#  - ────────────────── - ──────────── - ──────────── + ─────────── + ─────── +
#            4                 4              4              4           4
#         cos (γ)           cos (γ)        cos (γ)        cos (γ)     cos (γ)
#
#               2    4                      2    3                      2    2
# u__{\urcorner} ⋅sin (γ)   4⋅u__{\urcorner} ⋅sin (γ)   2⋅u__{\urcorner} ⋅sin (γ
# ─────────────────────── + ───────────────────────── - ────────────────────────
#            4                          4                           2
#         cos (γ)                    cos (γ)                     cos (γ)
#
#                     2    2                      2                          2
# )   2⋅u__{\urcorner} ⋅sin (γ)   4⋅u__{\urcorner} ⋅sin(γ)   4⋅u__{\urcorner} ⋅s
# ─ + ───────────────────────── - ──────────────────────── - ───────────────────
#                 4                          2                          4
#              cos (γ)                    cos (γ)                    cos (γ)
#
#                                           2                   2⎞
# in(γ)                 2   2⋅u__{\urcorner}    3⋅u__{\urcorner} ⎟
# ───── + u__{\urcorner}  - ───────────────── - ─────────────────⎟ + u__{\ulcorn
#                                   2                   4        ⎟
#                                cos (γ)             cos (γ)     ⎠
#
#     ⎛     3    4         3    2         3    2         2                   4
#     ⎜  2⋅a ⋅sin (γ)   2⋅a ⋅sin (γ)   2⋅a ⋅sin (γ)   4⋅a ⋅u__{\urcorner}⋅sin (γ
# er}⋅⎜- ──────────── + ──────────── + ──────────── - ──────────────────────────
#     ⎜       4              2              4                      4
#     ⎝    cos (γ)        cos (γ)        cos (γ)                cos (γ)
#
#        2                   3         2                   2         2
# )   8⋅a ⋅u__{\urcorner}⋅sin (γ)   6⋅a ⋅u__{\urcorner}⋅sin (γ)   4⋅a ⋅u__{\urco
# ─ - ─────────────────────────── + ─────────────────────────── + ──────────────
#                  4                             2                            2
#               cos (γ)                       cos (γ)                      cos (
#
#                   2                                                  2
# rner}⋅sin(γ)   8⋅a ⋅u__{\urcorner}⋅sin(γ)      2                  4⋅a ⋅u__{\ur
# ──────────── + ────────────────────────── - 2⋅a ⋅u__{\urcorner} + ────────────
#                            4                                               4
# γ)                      cos (γ)                                         cos (γ
#
#                2    3           2    2           2    2           2
# corner}   2⋅a⋅b ⋅sin (γ)   2⋅a⋅b ⋅sin (γ)   2⋅a⋅b ⋅sin (γ)   2⋅a⋅b ⋅sin(γ)   2
# ─────── + ────────────── + ────────────── + ────────────── + ───────────── - ─
#                 4                2                4                2
# )            cos (γ)          cos (γ)          cos (γ)          cos (γ)
#
#     2                         2                     2    4
# ⋅a⋅b ⋅sin(γ)        2    2⋅a⋅b    2⋅a⋅u__{\urcorner} ⋅sin (γ)   6⋅a⋅u__{\urcor
# ──────────── - 2⋅a⋅b  - ─────── - ─────────────────────────── - ──────────────
#      4                     4                   4                             4
#   cos (γ)               cos (γ)             cos (γ)                       cos
#
#     2    3                        2    2                        2    2
# ner} ⋅sin (γ)   4⋅a⋅u__{\urcorner} ⋅sin (γ)   2⋅a⋅u__{\urcorner} ⋅sin (γ)   6⋅
# ───────────── + ─────────────────────────── - ─────────────────────────── + ──
#                              2                             4
# (γ)                       cos (γ)                       cos (γ)
#
#                 2                            2
# a⋅u__{\urcorner} ⋅sin(γ)   6⋅a⋅u__{\urcorner} ⋅sin(γ)                     2
# ──────────────────────── + ────────────────────────── - 2⋅a⋅u__{\urcorner}  +
#           2                            4
#        cos (γ)                      cos (γ)
#
#                   2                     2      2                   2         2
# 2⋅a⋅u__{\urcorner}    4⋅a⋅u__{\urcorner}    2⋅b ⋅u__{\urcorner}⋅sin (γ)   4⋅b
# ─────────────────── + ─────────────────── + ─────────────────────────── + ────
#          2                     4                         2
#       cos (γ)               cos (γ)                   cos (γ)
#
#                                                   2               ⎞
# ⋅u__{\urcorner}⋅sin(γ)      2                  2⋅b ⋅u__{\urcorner}⎟
# ────────────────────── - 2⋅b ⋅u__{\urcorner} + ───────────────────⎟
#         2                                               2         ⎟
#      cos (γ)                                         cos (γ)      ⎠

# %% [markdown]
# Collection of coefficients $A, B, C$ corresponding to the powers of $x^\ulcorner$, i.e. $A (x^\ulcorner)^2 + B x^\ulcorner + C$
# is done using the list comprehension available in Pythin which delivers. For example,
# `[i for i in [2,1,0]]` renders a list `[2,1,0]`. At the place of `i` we apply the `expr.coeff(x_ul,i)` function
# delivering the coefficient associated with $(x^\ulcorner)^i$

# %%
A_, B_, C_ = [ Eq_UOU_x_rhs_collect.coeff(u_ul,i) for i in [2,1,0]]

# %%
A_simp_ = sp.trigsimp(A_)
A_simp_
# Out:
#      2                      2
#   2⋅a ⋅sin(γ)      2     3⋅a     12⋅a⋅u__{\urcorner}⋅sin(γ)
# - ─────────── + 4⋅a  - ─────── - ────────────────────────── + 8⋅a⋅u__{\urcorne
#        2                  2                  2
#     cos (γ)            cos (γ)            cos (γ)
#
#                               2               2                    2
#      12⋅a⋅u__{\urcorner}   2⋅b ⋅sin(γ)     2⋅b     8⋅u__{\urcorner} ⋅sin(γ)
# r} - ─────────────────── + ─────────── + ─────── - ──────────────────────── +
#               2                 2           2                 2
#            cos (γ)           cos (γ)     cos (γ)           cos (γ)
#
#                                     2
#                 2   8⋅u__{\urcorner}
# 4⋅u__{\urcorner}  - ─────────────────
#                             2
#                          cos (γ)

# %%
B_simp_ = sp.trigsimp(B_)
B_simp_
# Out:
#               3        2                                                    2
#      3     4⋅a     12⋅a ⋅u__{\urcorner}⋅sin(γ)       2                  14⋅a ⋅
# - 4⋅a  + ─────── + ─────────────────────────── - 12⋅a ⋅u__{\urcorner} + ──────
#             2                   2
#          cos (γ)             cos (γ)
#
#                                              2
# u__{\urcorner}        2   12⋅a⋅u__{\urcorner} ⋅sin(γ)                     2
# ────────────── - 4⋅a⋅b  + ─────────────────────────── - 8⋅a⋅u__{\urcorner}  +
#    2                                   2
# cos (γ)                             cos (γ)
#
#                    2      2                                                  2
# 12⋅a⋅u__{\urcorner}    4⋅b ⋅u__{\urcorner}⋅sin(γ)      2                  4⋅b
# ──────────────────── + ────────────────────────── - 4⋅b ⋅u__{\urcorner} + ────
#          2                         2
#       cos (γ)                   cos (γ)
#
#
# ⋅u__{\urcorner}
# ───────────────
#      2
#   cos (γ)

# %%
C_simp_ = sp.trigsimp(C_)
C_simp_
# Out:
#                ⎛            3       2
#                ⎜   3     4⋅a     2⋅a ⋅u__{\urcorner}⋅sin(γ)      2
# u__{\urcorner}⋅⎜4⋅a  - ─────── - ────────────────────────── + 4⋅a ⋅u__{\urcorn
#                ⎜          2                  2
#                ⎝       cos (γ)            cos (γ)
#
#          2                              2                            2
#       3⋅a ⋅u__{\urcorner}        2   2⋅b ⋅u__{\urcorner}⋅sin(γ)   2⋅b ⋅u__{\ur
# er} - ─────────────────── + 4⋅a⋅b  + ────────────────────────── + ────────────
#                2                                 2                         2
#             cos (γ)                           cos (γ)                   cos (γ
#
#        ⎞
# corner}⎟
# ───────⎟
#        ⎟
# )      ⎠

# %% [markdown]
# Prepare the two solutions of a quadratic equation as an expression with $A, B, C$ as parameters

# %%
A, B, C = sp.symbols('A, B, C')
u_ul_sol1, u_ul_sol2 = sp.solve( A * u_ul**2 + B * u_ul + C, u_ul )
u_ul_sol1, u_ul_sol2
# Out:
# ⎛        _____________   ⎛       _____________⎞ ⎞
# ⎜       ╱           2    ⎜      ╱           2 ⎟ ⎟
# ⎜-B + ╲╱  -4⋅A⋅C + B    -⎝B + ╲╱  -4⋅A⋅C + B  ⎠ ⎟
# ⎜─────────────────────, ────────────────────────⎟
# ⎝         2⋅A                     2⋅A           ⎠

# %% [markdown]
# **Remark:** Cover the whole solution space

# %%
sp.Eq( B**2 - 4*A*C, 0 ).subs({A: A_simp_, B: B_simp_, C: C_simp_})
# Out:
#
#                    ⎛            3       2
#                    ⎜   3     4⋅a     2⋅a ⋅u__{\urcorner}⋅sin(γ)      2
# - 4⋅u__{\urcorner}⋅⎜4⋅a  - ─────── - ────────────────────────── + 4⋅a ⋅u__{\ur
#                    ⎜          2                  2
#                    ⎝       cos (γ)            cos (γ)
#
#
#              2                              2                            2
#           3⋅a ⋅u__{\urcorner}        2   2⋅b ⋅u__{\urcorner}⋅sin(γ)   2⋅b ⋅u__
# corner} - ─────────────────── + 4⋅a⋅b  + ────────────────────────── + ────────
#                    2                                 2
#                 cos (γ)                           cos (γ)                   co
#
#
#            ⎞ ⎛     2                      2
# {\urcorner}⎟ ⎜  2⋅a ⋅sin(γ)      2     3⋅a     12⋅a⋅u__{\urcorner}⋅sin(γ)
# ───────────⎟⋅⎜- ─────────── + 4⋅a  - ─────── - ────────────────────────── + 8⋅
#  2         ⎟ ⎜       2                  2                  2
# s (γ)      ⎠ ⎝    cos (γ)            cos (γ)            cos (γ)
#
#
#                                             2               2
#                    12⋅a⋅u__{\urcorner}   2⋅b ⋅sin(γ)     2⋅b     8⋅u__{\urcorn
# a⋅u__{\urcorner} - ─────────────────── + ─────────── + ─────── - ─────────────
#                             2                 2           2                 2
#                          cos (γ)           cos (γ)     cos (γ)           cos (
#
#
#    2                                              2⎞   ⎛              3
# er} ⋅sin(γ)                   2   8⋅u__{\urcorner} ⎟   ⎜     3     4⋅a     12⋅
# ─────────── + 4⋅u__{\urcorner}  - ─────────────────⎟ + ⎜- 4⋅a  + ─────── + ───
#                                           2        ⎟   ⎜            2
# γ)                                     cos (γ)     ⎠   ⎝         cos (γ)
#
#
#  2                                                    2
# a ⋅u__{\urcorner}⋅sin(γ)       2                  14⋅a ⋅u__{\urcorner}
# ──────────────────────── - 12⋅a ⋅u__{\urcorner} + ──────────────────── - 4⋅a⋅b
#           2                                                2
#        cos (γ)                                          cos (γ)
#
#
#                        2                                                   2
# 2   12⋅a⋅u__{\urcorner} ⋅sin(γ)                     2   12⋅a⋅u__{\urcorner}
#   + ─────────────────────────── - 8⋅a⋅u__{\urcorner}  + ──────────────────── +
#                  2                                               2
#               cos (γ)                                         cos (γ)
#
#                                                                         2
#     2                                                  2               ⎞
#  4⋅b ⋅u__{\urcorner}⋅sin(γ)      2                  4⋅b ⋅u__{\urcorner}⎟
#  ────────────────────────── - 4⋅b ⋅u__{\urcorner} + ───────────────────⎟  = 0
#              2                                               2         ⎟
#           cos (γ)                                         cos (γ)      ⎠

# %% [markdown]
# Substitute for the parameters $A, B, C$ to obtain the solution.
#
# **Remark**: the second solution is relevant for the mountain/valley distribution
# considered in the waterbomb shells. Nevertheless, it would be interesting to
# combine the two solutions to get a complete kinematics of the cell regardlessly
# of the mountain/valley distribution within the cell.

# %%
u_ul_sol2_ = u_ul_sol2.subs({A: A_, B: B_, C: C_})
sp.trigsimp(u_ul_sol2_)
# Out:
# ⎛
# ⎜
# ⎜   3    2                                       2                   3
# ⎜2⋅a ⋅sin (γ)      3    4         3    2      8⋅a ⋅u__{\urcorner}⋅sin (γ)   4⋅
# ⎜──────────── - 2⋅a ⋅tan (γ) + 2⋅a ⋅tan (γ) - ─────────────────────────── + ──
# ⎜     4                                                    4
# ⎝  cos (γ)                                              cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2                            2
# a ⋅u__{\urcorner}⋅sin(γ)   8⋅a ⋅u__{\urcorner}⋅sin(γ)      2
# ──────────────────────── + ────────────────────────── - 4⋅a ⋅u__{\urcorner}⋅ta
#           2                            4
#        cos (γ)                      cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                2
#  4         2                   2         2                  4⋅a ⋅u__{\urcorner
# n (γ) + 6⋅a ⋅u__{\urcorner}⋅tan (γ) - 2⋅a ⋅u__{\urcorner} + ──────────────────
#                                                                      4
#                                                                   cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#          2    3           2    2           2               2
# }   2⋅a⋅b ⋅sin (γ)   2⋅a⋅b ⋅sin (γ)   2⋅a⋅b ⋅sin(γ)   2⋅a⋅b ⋅sin(γ)        2
# ─ + ────────────── + ────────────── + ───────────── - ───────────── + 2⋅a⋅b ⋅t
#           4                4                2               4
#        cos (γ)          cos (γ)          cos (γ)         cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                         2                     2    3                        2
#   2           2    2⋅a⋅b    6⋅a⋅u__{\urcorner} ⋅sin (γ)   2⋅a⋅u__{\urcorner} ⋅
# an (γ) - 2⋅a⋅b  - ─────── - ─────────────────────────── - ────────────────────
#                      4                   4                             4
#                   cos (γ)             cos (γ)                       cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2                        2                            2
# sin (γ)   6⋅a⋅u__{\urcorner} ⋅sin(γ)   6⋅a⋅u__{\urcorner} ⋅sin(γ)
# ─────── + ────────────────────────── + ────────────────────────── - 2⋅a⋅u__{\u
#                       2                            4
#                    cos (γ)                      cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#         2    4                        2    2                        2   2⋅a⋅u_
# rcorner} ⋅tan (γ) + 4⋅a⋅u__{\urcorner} ⋅tan (γ) - 2⋅a⋅u__{\urcorner}  + ──────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#             2                     2      2
# _{\urcorner}    4⋅a⋅u__{\urcorner}    4⋅b ⋅u__{\urcorner}⋅sin(γ)      2
# ───────────── + ─────────────────── + ────────────────────────── + 2⋅b ⋅u__{\u
#    2                     4                        2
# cos (γ)               cos (γ)                  cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#                   ⎛   2    2         2           2                         2
#                 2⋅⎝4⋅a ⋅sin (γ) + 2⋅a ⋅sin(γ) - a  + 8⋅a⋅u__{\urcorner}⋅sin (γ
#
#                                                                       ________
#                                                                      ╱
#                                             2                       ╱
#             2         2                  2⋅b ⋅u__{\urcorner}       ╱
# rcorner}⋅tan (γ) - 2⋅b ⋅u__{\urcorner} + ─────────────────── +    ╱    - 4⋅u__
#                                                   2              ╱
#                                                cos (γ)         ╲╱
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2             2
# ) + 12⋅a⋅u__{\urcorner}⋅sin(γ) + 4⋅a⋅u__{\urcorner} - 2⋅b ⋅sin(γ) - 2⋅b  + 4⋅u
#
# ______________________________________________________________________________
#
#             ⎛            3       2
#             ⎜   3     4⋅a     2⋅a ⋅u__{\urcorner}⋅sin(γ)      2
# {\urcorner}⋅⎜4⋅a  - ─────── - ────────────────────────── + 4⋅a ⋅u__{\urcorner}
#             ⎜          2                  2
#             ⎝       cos (γ)            cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#              2    2                      2                          2⎞
# __{\urcorner} ⋅sin (γ) + 8⋅u__{\urcorner} ⋅sin(γ) + 4⋅u__{\urcorner} ⎠
#
# ______________________________________________________________________________
#
#       2                              2                            2
#    3⋅a ⋅u__{\urcorner}        2   2⋅b ⋅u__{\urcorner}⋅sin(γ)   2⋅b ⋅u__{\urcor
#  - ─────────────────── + 4⋅a⋅b  + ────────────────────────── + ───────────────
#             2                                 2                         2
#          cos (γ)                           cos (γ)                   cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#     ⎞ ⎛     2                      2
# ner}⎟ ⎜  2⋅a ⋅sin(γ)      2     3⋅a     12⋅a⋅u__{\urcorner}⋅sin(γ)
# ────⎟⋅⎜- ─────────── + 4⋅a  - ─────── - ────────────────────────── + 8⋅a⋅u__{\
#     ⎟ ⎜       2                  2                  2
#     ⎠ ⎝    cos (γ)            cos (γ)            cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#                                      2               2                    2
#             12⋅a⋅u__{\urcorner}   2⋅b ⋅sin(γ)     2⋅b     8⋅u__{\urcorner} ⋅si
# urcorner} - ─────────────────── + ─────────── + ─────── - ────────────────────
#                      2                 2           2                 2
#                   cos (γ)           cos (γ)     cos (γ)           cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#                                            2⎞     ⎛   3    2         2
# n(γ)                   2   8⋅u__{\urcorner} ⎟   4⋅⎝2⋅a ⋅sin (γ) + 6⋅a ⋅u__{\ur
# ──── + 4⋅u__{\urcorner}  - ─────────────────⎟ + ──────────────────────────────
#                                    2        ⎟
#                                 cos (γ)     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#            2         2                          2                       2    2
# corner}⋅sin (γ) + 6⋅a ⋅u__{\urcorner}⋅sin(γ) + a ⋅u__{\urcorner} + 2⋅a⋅b ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#
#            2                     2    2                        2
# (γ) - 2⋅a⋅b  + 4⋅a⋅u__{\urcorner} ⋅sin (γ) + 6⋅a⋅u__{\urcorner} ⋅sin(γ) + 2⋅a⋅
# ──────────────────────────────────────────────────────────────────────────────
#                       4
#                    cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____________________________________________________________________________⎞
#                                                                            2 ⎟
#               2      2                   2         2                      ⎞  ⎟
# u__{\urcorner}  + 2⋅b ⋅u__{\urcorner}⋅sin (γ) + 2⋅b ⋅u__{\urcorner}⋅sin(γ)⎠  ⎟
# ──────────────────────────────────────────────────────────────────────────── ⎟
#                                                                              ⎟
#                                                                              ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#     2
# ⋅cos (γ)
#
#
# ────────

# %% [markdown]
# Verify that the condition for constant scalar product $UOU$ is fulfilled

# %%
sp.simplify(Eq_UOU_x_rhs_collect.subs(u_ul, u_ul_sol2_))
# Out:
# 0

# %% [markdown]
# **Remark:** Solution `x_ul_sol1_` does not satisfy the constant sector angle condition. This is due to the square applied at both sides of the condition that allows for a second solution with alternating signs on left and right hand side.

# %% [markdown]
# Further, verify that for $x^\urcorner = a$ and $\gamma = 0$ (fully folded state), $x^\ulcorner = -a$

# %%
sp.simplify(u_ul_sol2_.subs(u_ur,a).subs(gamma,0))
# Out:
#   ⎛                   _______________________⎞
#   ⎜   2      2       ╱    4      2  2      4 ⎟
# a⋅⎝3⋅a  - 2⋅b  + 2⋅╲╱  4⋅a  + 7⋅a ⋅b  - 2⋅b  ⎠
# ──────────────────────────────────────────────
#                     2      2
#                  7⋅a  - 2⋅b

# %%
sp.limit(u_ul_sol2_.subs(u_ur,a).subs(b,a), gamma, sp.pi/2)
# Out:
# 6⋅√21⋅a   31⋅a
# ─────── + ────
#    41      41

# %% [markdown]
# **TODO**: Consider the control of folding using a dimensionless parameter $\eta, \zeta$ representing the
#     unfolded and folded states instead of fold angle $\gamma$.

# %%
v_ul_sol2
# Out:
#         ______________________________________________________________________
#        ╱    2    2                                                        2
#      ╲╱  - a ⋅sin (γ) + 2⋅a⋅u__{\ulcorner}⋅sin(γ) + 2⋅a⋅u__{\ulcorner} - b ⋅si
# -b + ─────────────────────────────────────────────────────────────────────────
#                                                                     cos(γ)
#
# __________________________________________________________
#  2       2                   2                          2
# n (γ) + b  - 2⋅u__{\ulcorner} ⋅sin(γ) - 2⋅u__{\ulcorner}
# ──────────────────────────────────────────────────────────

# %% [markdown]
# ### Find a solution for $\gamma = \pi/3$

# %%
y_ul_sol1_pi3, y_ul_sol2_pi3 = sp.solve(Eq_UOU_x.subs(gamma,sp.pi/3), x_ul)

# %%
y_ul_sol1_pi3
# Out:
#
#         3    2                                       2    2
# - 2⋅√3⋅a  - a ⋅x__{\urcorner} + 2⋅√3⋅a⋅x__{\urcorner}  - b ⋅x__{\urcorner} - ╲
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ____________________________________________________________________________
#  ╱     6          5                      4  2       4               2
# ╱  12⋅a  - 28⋅√3⋅a ⋅x__{\urcorner} - 16⋅a ⋅b  + 73⋅a ⋅x__{\urcorner}  + 20⋅√3⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       ⎛
#                                                                     2⋅⎝2⋅√3⋅a⋅
#
# ______________________________________________________________________________
#  3  2                         3               3      2  4       2  2
# a ⋅b ⋅x__{\urcorner} - 28⋅√3⋅a ⋅x__{\urcorner}  + 4⋅a ⋅b  - 10⋅a ⋅b ⋅x__{\urco
# ──────────────────────────────────────────────────────────────────────────────
#                   2                   2⎞
# x__{\urcorner} + b  - 3⋅x__{\urcorner} ⎠
#
# ______________________________________________________________________________
#      2       2               4            2               3      4
# rner}  + 12⋅a ⋅x__{\urcorner}  - 12⋅√3⋅a⋅b ⋅x__{\urcorner}  - 3⋅b ⋅x__{\urcorn
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____________________________
#    2       2               4
# er}  + 12⋅b ⋅x__{\urcorner}
# ─────────────────────────────

# %%
y_ul_sol2_pi3
# Out:
#
#         3    2                                       2    2
# - 2⋅√3⋅a  - a ⋅x__{\urcorner} + 2⋅√3⋅a⋅x__{\urcorner}  - b ⋅x__{\urcorner} + ╲
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ____________________________________________________________________________
#  ╱     6          5                      4  2       4               2
# ╱  12⋅a  - 28⋅√3⋅a ⋅x__{\urcorner} - 16⋅a ⋅b  + 73⋅a ⋅x__{\urcorner}  + 20⋅√3⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       ⎛
#                                                                     2⋅⎝2⋅√3⋅a⋅
#
# ______________________________________________________________________________
#  3  2                         3               3      2  4       2  2
# a ⋅b ⋅x__{\urcorner} - 28⋅√3⋅a ⋅x__{\urcorner}  + 4⋅a ⋅b  - 10⋅a ⋅b ⋅x__{\urco
# ──────────────────────────────────────────────────────────────────────────────
#                   2                   2⎞
# x__{\urcorner} + b  - 3⋅x__{\urcorner} ⎠
#
# ______________________________________________________________________________
#      2       2               4            2               3      4
# rner}  + 12⋅a ⋅x__{\urcorner}  - 12⋅√3⋅a⋅b ⋅x__{\urcorner}  - 3⋅b ⋅x__{\urcorn
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# _____________________________
#    2       2               4
# er}  + 12⋅b ⋅x__{\urcorner}
# ─────────────────────────────

# %%
x_ul_sol1_pi6, x_ul_sol2_pi6 = sp.solve( Eq_UOU_x.subs( gamma, sp.pi/6 ), x_ul)

# %%
x_ul_sol1_pi6
# Out:
#                                                                         ______
#           2                                       2                    ╱
#    3   3⋅a ⋅x__{\urcorner}                   2   b ⋅x__{\urcorner}   ╲╱  -(2⋅a
# - a  - ─────────────────── + a⋅x__{\urcorner}  + ───────────────── - ─────────
#                 2                                        2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                    ⎛ 2                           2                   2⎞ ⎛
#  - x__{\urcorner})⋅⎝a  - 4⋅a⋅x__{\urcorner} - 3⋅b  + 4⋅x__{\urcorner} ⎠⋅⎝- 2⋅a
# ──────────────────────────────────────────────────────────────────────────────
#                                                             2
# ──────────────────────────────────────────────────────────────────────────────
#                            2                 2
#      2⋅a⋅x__{\urcorner} + b  - x__{\urcorner}
#
# ____________________________________________________
# 3    2                       2    2               ⎞
#   + a ⋅x__{\urcorner} + 2⋅a⋅b  + b ⋅x__{\urcorner}⎠
# ────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────

# %%
x_ul_sol2_pi6
# Out:
#                                                                         ______
#           2                                       2                    ╱
#    3   3⋅a ⋅x__{\urcorner}                   2   b ⋅x__{\urcorner}   ╲╱  -(2⋅a
# - a  - ─────────────────── + a⋅x__{\urcorner}  + ───────────────── + ─────────
#                 2                                        2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ______________________________________________________________________________
#                    ⎛ 2                           2                   2⎞ ⎛
#  - x__{\urcorner})⋅⎝a  - 4⋅a⋅x__{\urcorner} - 3⋅b  + 4⋅x__{\urcorner} ⎠⋅⎝- 2⋅a
# ──────────────────────────────────────────────────────────────────────────────
#                                                             2
# ──────────────────────────────────────────────────────────────────────────────
#                            2                 2
#      2⋅a⋅x__{\urcorner} + b  - x__{\urcorner}
#
# ____________________________________________________
# 3    2                       2    2               ⎞
#   + a ⋅x__{\urcorner} + 2⋅a⋅b  + b ⋅x__{\urcorner}⎠
# ────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────

# %% [markdown]
# ## Solve for $U^\urcorner(y^\urcorner)$ and $U^\ulcorner(y^\ulcorner)$

# %%
xz_ur_sol1, yz_ur_sol2 = sp.solve({Eq_UOV_r, Eq_VUO_r}, [x_ur, z_ur])
xz_ul_sol1, yz_ul_sol2 = sp.solve({Eq_UOV_l, Eq_VUO_l}, [x_ul, z_ul])

# %% [markdown]
# first solution for $x^\urcorner$ and $z^\urcorner$

# %%
xz_ur_sol1
# Out:
# ⎛              ______________________                       __________________
# ⎜             ╱  2                 2                       ╱  2
# ⎝a⋅sin(γ) - ╲╱  b  - y__{\urcorner}  ⋅cos(γ), a⋅cos(γ) + ╲╱  b  - y__{\urcorne
#
# ____       ⎞
#   2        ⎟
# r}  ⋅sin(γ)⎠

# %%
x_ur_sol, z_ur_sol = xz_ur_sol1

# %% [markdown]
# first solution for $x^\ulcorner$ and $z^\ulcorner$

# %%
xz_ul_sol1
# Out:
# ⎛               ______________________                       _________________
# ⎜              ╱  2                 2                       ╱  2
# ⎝-a⋅sin(γ) - ╲╱  b  - y__{\ulcorner}  ⋅cos(γ), a⋅cos(γ) - ╲╱  b  - y__{\ulcorn
#
# _____       ⎞
#    2        ⎟
# er}  ⋅sin(γ)⎠

# %%
x_ul_sol, z_ul_sol = xz_ul_sol1

# %%
subs_xz = {x_ur:x_ur_sol, z_ur:z_ur_sol,
           x_ul:x_ul_sol, z_ul:z_ul_sol}
subs_xz
# Out:
# ⎧                               ______________________
# ⎨                              ╱  2                 2
# ⎩x__{\ulcorner}: -a⋅sin(γ) - ╲╱  b  - y__{\ulcorner}  ⋅cos(γ), x__{\urcorner}:
#
#                ______________________                                       __
#               ╱  2                 2                                       ╱
#  a⋅sin(γ) - ╲╱  b  - y__{\urcorner}  ⋅cos(γ), z__{\ulcorner}: a⋅cos(γ) - ╲╱  b
#
# ____________________                                       ___________________
# 2                 2                                       ╱  2
#   - y__{\ulcorner}  ⋅sin(γ), z__{\urcorner}: a⋅cos(γ) + ╲╱  b  - y__{\urcorner
#
# ___       ⎫
#  2        ⎬
# }  ⋅sin(γ)⎭

# %% [markdown]
# ### Solutions $U^\urcorner(y^\urcorner)$ and $U^\ulcorner(y^\ulcorner)$

# %%
U_ur_y = U_ur_1.subs(subs_xz)
U_ul_y = U_ul_1.subs(subs_xz)
U_ul_y, U_ur_y
# Out:
# ⎛⎡               ______________________       ⎤  ⎡              ______________
# ⎜⎢              ╱  2                 2        ⎥  ⎢             ╱  2
# ⎜⎢-a⋅sin(γ) - ╲╱  b  - y__{\ulcorner}  ⋅cos(γ)⎥  ⎢a⋅sin(γ) - ╲╱  b  - y__{\urc
# ⎜⎢                                            ⎥  ⎢
# ⎜⎢               y__{\ulcorner}               ⎥, ⎢              y__{\urcorner}
# ⎜⎢                                            ⎥  ⎢
# ⎜⎢              ______________________        ⎥  ⎢              ______________
# ⎜⎢             ╱  2                 2         ⎥  ⎢             ╱  2
# ⎝⎣a⋅cos(γ) - ╲╱  b  - y__{\ulcorner}  ⋅sin(γ) ⎦  ⎣a⋅cos(γ) + ╲╱  b  - y__{\urc
#
# ________       ⎤⎞
#       2        ⎥⎟
# orner}  ⋅cos(γ)⎥⎟
#                ⎥⎟
#                ⎥⎟
#                ⎥⎟
# ________       ⎥⎟
#       2        ⎥⎟
# orner}  ⋅sin(γ)⎦⎠

# %% [markdown]
# Verify the unfolded - flat state with $\gamma = \frac{\pi}{2}$

# %%
U_ul_y.subs(gamma,sp.pi/2).subs(y_ul,b), U_ur_y.subs(gamma, sp.pi/2).subs(y_ur,b)
# Out:
# ⎛⎡-a⎤  ⎡a⎤⎞
# ⎜⎢  ⎥  ⎢ ⎥⎟
# ⎜⎢b ⎥, ⎢b⎥⎟
# ⎜⎢  ⎥  ⎢ ⎥⎟
# ⎝⎣0 ⎦  ⎣0⎦⎠

# %%
Eq_UOU_y = Eq_UOU.subs(subs_xz)
Eq_UOU_y
# Out:
#                                             ⎛               __________________
#    2    2                                   ⎜              ╱  2
# - a  + b  = y__{\ulcorner}⋅y__{\urcorner} + ⎝-a⋅sin(γ) - ╲╱  b  - y__{\ulcorne
#
# ____       ⎞ ⎛              ______________________       ⎞   ⎛              __
#   2        ⎟ ⎜             ╱  2                 2        ⎟   ⎜             ╱
# r}  ⋅cos(γ)⎠⋅⎝a⋅sin(γ) - ╲╱  b  - y__{\urcorner}  ⋅cos(γ)⎠ + ⎝a⋅cos(γ) - ╲╱  b
#
# ____________________       ⎞ ⎛              ______________________       ⎞
# 2                 2        ⎟ ⎜             ╱  2                 2        ⎟
#   - y__{\ulcorner}  ⋅sin(γ)⎠⋅⎝a⋅cos(γ) + ╲╱  b  - y__{\urcorner}  ⋅sin(γ)⎠

# %%
dy_ul, dy_ur = sp.symbols(r'\Delta{y}^\ulcorner, \Delta{y}^\urcorner')
dy_ul, dy_ur
# Out:
# (\Delta{y}__\ulcorner, \Delta{y}__\urcorner)

# %%
dy_ul_, dy_ur_ = [sp.Eq(dy_u, sp.sqrt( b**2 - y_u**2 )) for dy_u, y_u in zip([dy_ul, dy_ur],[y_ul, y_ur])]
dy_ul_, dy_ur_
# Out:
# ⎛                          ______________________                            _
# ⎜                         ╱  2                 2                            ╱
# ⎝\Delta{y}__\ulcorner = ╲╱  b  - y__{\ulcorner}  , \Delta{y}__\urcorner = ╲╱
#
# _____________________⎞
#  2                 2 ⎟
# b  - y__{\urcorner}  ⎠

# %%
subs_y_u = {y_u: sp.solve(dy_u_, y_u)[1] for dy_u_, y_u in zip([dy_ul_, dy_ur_],[y_ul, y_ur])}
subs_y_u
# Out:
# ⎧                   ______________________________                     _______
# ⎨                  ╱                       2    2                     ╱
# ⎩y__{\ulcorner}: ╲╱  - \Delta{y}__\ulcorner  + b  , y__{\urcorner}: ╲╱  - \Del
#
# _______________________⎫
#                 2    2 ⎬
# ta{y}__\urcorner  + b  ⎭

# %%
sp.simplify(Eq_UOU_y.subs(subs_y_u))
# Out:
#                                _______________________                 _______
#  2    2      2                ╱                     2                 ╱
# a  - b  = - a ⋅cos(2⋅γ) + a⋅╲╱  \Delta{y}__\ulcorner  ⋅sin(2⋅γ) - a⋅╲╱  \Delta
#
# ________________               ______________________________    _____________
#               2               ╱                       2    2    ╱
# {y}__\urcorner  ⋅sin(2⋅γ) - ╲╱  - \Delta{y}__\ulcorner  + b  ⋅╲╱  - \Delta{y}_
#
# _________________      _______________________    _______________________
#           2    2      ╱                     2    ╱                     2
# _\urcorner  + b   - ╲╱  \Delta{y}__\ulcorner  ⋅╲╱  \Delta{y}__\urcorner  ⋅cos(
#
#
#
# 2⋅γ)

# %% [markdown]
# This equation can be solved for $y^\urcorner$ in `maple`. However it is very long.
# Attempting further simplifications.

# %% [markdown]
# ## Solve for $U^\urcorner(z^\urcorner)$ and $U^\ulcorner(z^\ulcorner)$

# %%
xy_ur_sol1, xy_ur_sol2 = sp.solve({Eq_UOV_r, Eq_VUO_r}, [x_ur, y_ur])
xy_ul_sol1, xy_ul_sol2 = sp.solve({Eq_UOV_l, Eq_VUO_l}, [x_ul, y_ul])

# %%
x_ur_sol, y_ur_sol = xy_ur_sol1
x_ul_sol, y_ul_sol = xy_ul_sol1

# %%
x_ur_sol, x_ul_sol
# Out:
# ⎛a - z__{\urcorner}⋅cos(γ)  -a + z__{\ulcorner}⋅cos(γ)⎞
# ⎜─────────────────────────, ──────────────────────────⎟
# ⎝          sin(γ)                     sin(γ)          ⎠

# %%
y_ur_sol, y_ul_sol
# Out:
# ⎛      _______________________________________________________________________
# ⎜     ╱    2                                             2   ⎛ 2    2⎞    2
# ⎜    ╱  - a  + 2⋅a⋅z__{\urcorner}⋅cos(γ) - z__{\urcorner}  + ⎝a  + b ⎠⋅sin (γ)
# ⎜   ╱   ──────────────────────────────────────────────────────────────────────
# ⎜  ╱                                      2
# ⎝╲╱                                    sin (γ)
#
# _        _____________________________________________________________________
#         ╱    2                                             2   ⎛ 2    2⎞    2
#        ╱  - a  + 2⋅a⋅z__{\ulcorner}⋅cos(γ) - z__{\ulcorner}  + ⎝a  + b ⎠⋅sin (
#  ,    ╱   ────────────────────────────────────────────────────────────────────
#      ╱                                      2
#    ╲╱                                    sin (γ)
#
# ___⎞
#    ⎟
# γ) ⎟
# ── ⎟
#    ⎟
#    ⎠

# %%
subs_xy = {x_ur:x_ur_sol, y_ur:y_ur_sol,
           x_ul:x_ul_sol, y_ul:y_ul_sol}

# %%
Eq_UOU_z = Eq_UOU.subs(subs_xy)
sp.solve(Eq_UOU_z.subs(z_ul,0).subs(z_ur,0), gamma)
# Out:
# ⎡π  3⋅π⎤
# ⎢─, ───⎥
# ⎣2   2 ⎦

# %%
sp.solve(Eq_UOU_z.subs(gamma,sp.pi/3), z_ul)
# Out:
# ⎡                                                                      _______
# ⎢ 2                                              2                    ╱
# ⎢a ⋅z__{\urcorner}      2                   2   b ⋅z__{\urcorner}   ╲╱  z__{\u
# ⎢───────────────── + a⋅b  - a⋅z__{\urcorner}  + ───────────────── - ──────────
# ⎢        2                                              2
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎣                                                                         2⋅a⋅
#
# ______________________________________________________________________________
#          ⎛ 2                       2    2               ⎞ ⎛ 2
# rcorner}⋅⎝a ⋅z__{\urcorner} - 4⋅a⋅b  + b ⋅z__{\urcorner}⎠⋅⎝a  - 4⋅a⋅z__{\urcor
# ──────────────────────────────────────────────────────────────────────────────
#                                                   2
# ──────────────────────────────────────────────────────────────────────────────
#                   2                 2
# z__{\urcorner} + b  - z__{\urcorner}
#
# _________________________________
#           2                   2⎞    2
# ner} - 3⋅b  + 4⋅z__{\urcorner} ⎠   a ⋅z__{\urcorner}      2
# ─────────────────────────────────  ───────────────── + a⋅b  - a⋅z__{\urcorner}
#                                            2
# ─────────────────────────────────, ───────────────────────────────────────────
#
#
#
#                            ___________________________________________________
#      2                    ╱                ⎛ 2                       2    2
# 2   b ⋅z__{\urcorner}   ╲╱  z__{\urcorner}⋅⎝a ⋅z__{\urcorner} - 4⋅a⋅b  + b ⋅z_
#   + ───────────────── + ──────────────────────────────────────────────────────
#             2
# ──────────────────────────────────────────────────────────────────────────────
#                                                     2                 2
#                               2⋅a⋅z__{\urcorner} + b  - z__{\urcorner}
#
# ___________________________________________________________________⎤
#             ⎞ ⎛ 2                           2                   2⎞ ⎥
# _{\urcorner}⎠⋅⎝a  - 4⋅a⋅z__{\urcorner} - 3⋅b  + 4⋅z__{\urcorner} ⎠ ⎥
# ───────────────────────────────────────────────────────────────────⎥
#       2                                                            ⎥
# ───────────────────────────────────────────────────────────────────⎥
#                                                                    ⎥
#                                                                    ⎦

# %% [markdown]
# # Solution with constant edge lengths

# %%
L2_UO_ur_0 = (U_ur_0.T * U_ur_0)[0]
L2_UV_r_0 = ((U_ur_0-V_r_0).T * (U_ur_0-V_r_0))[0]
L2_UO_ul_0 = (U_ul_0.T * U_ul_0)[0]
L2_UV_l_0 = ((U_ul_0-V_l_0).T * (U_ul_0-V_l_0))[0]
L2_UU_0 = ((U_ul_0-U_ur_0).T * (U_ul_0-U_ur_0))[0]
L2_UO_ur_0, L2_UV_r_0, L2_UO_ul_0, L2_UV_l_0, L2_UU_0
# Out:
# ⎛ 2    2   2          2   2    2   2           2     2⎞
# ⎝a  + b , b  + (a - c) , a  + b , b  + (-a + c) , 4⋅a ⎠

# %% [markdown]
# And in a general state of folding

# %%
L2_UO_ur_1 = (U_ur_1.T * U_ur_1)[0]
L2_UV_r_1 = ((U_ur_1-V_r_1).T * (U_ur_1-V_r_1))[0]
L2_UO_ul_1 = (U_ul_1.T * U_ul_1)[0]
L2_UV_l_1 = ((U_ul_1-V_r_1).T * (U_ul_1-V_l_1))[0]
L2_UU_1 = ((U_ul_1-U_ur_1).T * (U_ul_1-U_ur_1))[0]
L2_UO_ur_1, L2_UV_r_1, L2_UO_ul_1, L2_UV_l_1, L2_UU_1
# Out:
# ⎛              2                 2                 2                2
# ⎝x__{\urcorner}  + y__{\urcorner}  + z__{\urcorner} , y__{\urcorner}  + (-c⋅si
#
#                       2                               2                2
# n(γ) + x__{\urcorner})  + (-c⋅cos(γ) + z__{\urcorner}) , x__{\ulcorner}  + y__
#
#            2                 2                2
# {\ulcorner}  + z__{\ulcorner} , y__{\ulcorner}  + (-c⋅sin(γ) + x__{\ulcorner})
#
#                                                            2
# ⋅(c⋅sin(γ) + x__{\ulcorner}) + (-c⋅cos(γ) + z__{\ulcorner}) , (x__{\ulcorner}
#
#                  2                                    2
# - x__{\urcorner})  + (y__{\ulcorner} - y__{\urcorner})  + (z__{\ulcorner} - z_
#
#              2⎞
# _{\urcorner}) ⎠

# %%
Eq_L2_UO_ur = sp.Eq( L2_UO_ur_0, L2_UO_ur_1 ) #
Eq_L2_UV_r = sp.Eq( L2_UV_r_0, L2_UV_r_1 )
Eq_L2_UO_ul = sp.Eq( L2_UO_ul_0, L2_UO_ul_1 ) #
Eq_L2_UV_l = sp.Eq( L2_UV_l_0, L2_UV_l_1 )
Eq_L2_UU = sp.Eq( L2_UU_0, L2_UU_1 ) #

# %%
y_ur_sol, z_ur_sol = sp.solve({Eq_L2_UO_ur, Eq_L2_UV_r}, [y_ur, z_ur])[0]
y_ul_sol, z_ul_sol = sp.solve({Eq_L2_UO_ul, Eq_L2_UV_l}, [y_ul, z_ul])[0]

# %%
subs_yz_L = {y_ur:y_ur_sol, z_ur:z_ur_sol, y_ul:y_ul_sol, z_ul:z_ul_sol}

# %%
Eq_L2_UU_x = Eq_L2_UU.subs(subs_yz_L)
Eq_L2_UU_x
# Out:
#
#
#                                             ⎛         2
#    2                                    2   ⎜a - c⋅sin (γ)   a - x__{\urcorner
# 4⋅a  = (x__{\ulcorner} - x__{\urcorner})  + ⎜───────────── - ─────────────────
#                                             ⎝    cos(γ)                cos(γ)
#
#
#
#          2   ⎛      __________________________________________________________
#         ⎞    ⎜     ╱    2            2    4      ⎛ 2            2
# }⋅sin(γ)⎟    ⎜    ╱  - a  + 2⋅a⋅c - c ⋅sin (γ) + ⎝a  - 2⋅a⋅c + b  - x__{\ulcor
# ────────⎟  + ⎜   ╱   ─────────────────────────────────────────────────────────
#         ⎠    ⎜  ╱                                       2
#              ⎝╲╱                                     cos (γ)
#
#
# _______________         ______________________________________________________
#     2⎞    2            ╱    2                                             2
# ner} ⎠⋅cos (γ)        ╱  - a  + 2⋅a⋅x__{\urcorner}⋅sin(γ) - x__{\urcorner}  +
# ──────────────  -    ╱   ─────────────────────────────────────────────────────
#                     ╱                                      2
#                   ╲╱                                    cos (γ)
#
#                    2
# __________________⎞
# ⎛ 2    2⎞    2    ⎟
# ⎝a  + b ⎠⋅cos (γ) ⎟
# ───────────────── ⎟
#                   ⎟
#                   ⎠

# %%
eta = sp.symbols('eta')

# %% [markdown]
# To control the twist of the non-symmetric fold mode of the waterbomb base, let us link $x^\ulcorner$ with
# $x^\urcorner$ by setting
# \begin{align}
#  x^\ulcorner = - \eta \, x^\urcorner
# \end{align}

# %%
x_ul_ = - eta * x_ur

# %% [markdown]
# Finally, require that the length $|U^{\ulcorner\urcorner}| = 2a$ is equal to the original length
# at any state of folding

# %%
Eq_L2_UU_eta = Eq_L2_UU_x.subs(x_ul, x_ul_)
Eq_L2_UU_eta
# Out:
#
#
#                                                ⎛         2
#    2                                       2   ⎜a - c⋅sin (γ)   a - x__{\urcor
# 4⋅a  = (-η⋅x__{\urcorner} - x__{\urcorner})  + ⎜───────────── - ──────────────
#                                                ⎝    cos(γ)                cos(
#
#
#
#             2   ⎛      _______________________________________________________
#            ⎞    ⎜     ╱    2            2    4      ⎛ 2            2    2
# ner}⋅sin(γ)⎟    ⎜    ╱  - a  + 2⋅a⋅c - c ⋅sin (γ) + ⎝a  - 2⋅a⋅c + b  - η ⋅x__{
# ───────────⎟  + ⎜   ╱   ──────────────────────────────────────────────────────
# γ)         ⎠    ⎜  ╱                                        2
#                 ⎝╲╱                                      cos (γ)
#
#
# _____________________         ________________________________________________
#           2⎞    2            ╱    2
# \urcorner} ⎠⋅cos (γ)        ╱  - a  + 2⋅a⋅x__{\urcorner}⋅sin(γ) - x__{\urcorne
# ────────────────────  -    ╱   ───────────────────────────────────────────────
#                           ╱                                      2
#                         ╲╱                                    cos (γ)
#
#                          2
# ________________________⎞
#   2   ⎛ 2    2⎞    2    ⎟
# r}  + ⎝a  + b ⎠⋅cos (γ) ⎟
# ─────────────────────── ⎟
#                         ⎟
#                         ⎠

# %%
x_ur_sol_1, x_ur_sol_2 = sp.solve(Eq_L2_UU_eta.subs(gamma,0), x_ur)
x_ur_sol_1, x_ur_sol_2
# Out:
# ⎛          ________________________________             ______________________
# ⎜         ╱              2    2                        ╱           ⎛ 2    2⎞
# ⎜        ╱            - a  + b                        ╱           -⎝a  - b ⎠
# ⎜2⋅a⋅   ╱   ────────────────────────────── , -2⋅a⋅   ╱   ─────────────────────
# ⎜      ╱         2      2  2      2      2          ╱         2      2  2
# ⎝    ╲╱     - 4⋅a ⋅η + b ⋅η  + 2⋅b ⋅η + b         ╲╱     - 4⋅a ⋅η + b ⋅η  + 2⋅
#
# __________⎞
#           ⎟
#           ⎟
# ───────── ⎟
#  2      2 ⎟
# b ⋅η + b  ⎠

# %% [markdown]
# $\eta = 1$ recovers the symmetric case

# %%
sp.simplify(x_ur_sol_1.subs(eta,1))
# Out:
# a
