# %%
from bmcs_shell.folding.wb_shell_analysis import WBShellAnalysis
from bmcs_shell.folding.vmats2D_elastic import MATS2DElastic
import bmcs_utils.api as bu

# %%
tmodel = MATS2DElastic(E=28000 * 0.03, nu=0.2)

# %%
n_phi_plus=4
data = dict(alpha=1.24, a=500, b=900, c=400, n_phi_plus=n_phi_plus, n_x_plus=4)
wbm = WBShellAnalysis(F=-1000, tmodel=tmodel)
wbm.geo.trait_set(**data);

# %%
wbm.interact()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6da836f12e26> in <module>
# ----> 1 wbm.interact()
#
# ~/PycharmProjects/bmcs_utils/bmcs_utils/model.py in interact(self, **kw)
#      43
#      44     def interact(self,**kw):
# ---> 45         return AppWindow(self,**kw).interact()
#      46
#      47     def app(self,**kw):
#
# ~/PycharmProjects/bmcs_utils/bmcs_utils/app_window.py in interact(self)
#     133                              layout=ipw.Layout(align_items="stretch",
#     134                                                width="100%"))
# --> 135         self.model_tree.selected = True
#     136         display(app_print)
#     137
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     602             raise TraitError('The "%s" trait is read-only.' % self.name)
#     603         else:
# --> 604             self.set(obj, value)
#     605
#     606     def _validate(self, obj, value):
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     591             # we explicitly compare silent to True just in case the equality
#     592             # comparison above returns something other than True/False
# --> 593             obj._notify_trait(self.name, old_value, new_value)
#     594
#     595     def __set__(self, obj, value):
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1215
#    1216     def _notify_trait(self, name, old_value, new_value):
# -> 1217         self.notify_change(Bunch(
#    1218             name=name,
#    1219             old=old_value,
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1225     def notify_change(self, change):
#    1226         """Notify observers of a change event"""
# -> 1227         return self._notify_observers(change)
#    1228
#    1229     def _notify_observers(self, event):
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traitlets/traitlets.py in _notify_observers(self, event)
#    1262                 c = getattr(self, c.name)
#    1263
# -> 1264             c(event)
#    1265
#    1266     def _add_notifiers(self, handler, name, type):
#
# ~/PycharmProjects/bmcs_utils/bmcs_utils/app_window.py in select_node(self, event)
#     222         backend = controller.model.plot_backend
#     223         self.set_plot_backend(backend)
# --> 224         self.setup_plot(controller.model)
#     225         self.update_plot(controller.model)
#     226
#
# ~/PycharmProjects/bmcs_utils/bmcs_utils/app_window.py in setup_plot(self, model)
#     237         pb = self.plot_backend_table[self.current_plot_backend]
#     238         pb.clear_fig()
# --> 239         pb.setup_plot(model)
#     240
#     241     def update_plot(self, model):
#
# ~/PycharmProjects/bmcs_utils/bmcs_utils/app_window.py in setup_plot(self, model)
#      73         pass
#      74     def setup_plot(self, model):
# ---> 75         model.setup_plot(self)
#      76     def update_plot(self, model):
#      77         model.update_plot(self)
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_shell_analysis.py in setup_plot(self, pb)
#     122     def setup_plot(self, pb):
#     123
# --> 124         self.run()
#     125         U_1 = self.hist.U_t[-1]
#     126         X1_Id = self.xdomain.mesh.X_Id + (U_1.reshape(-1, 3) * 1)
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_shell_analysis.py in run(self)
#     112         s.tline.step = 1
#     113         s.tloop.verbose = False
# --> 114         s.run()
#     115
#     116     def get_max_vals(self):
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/sim_base.py in run(self)
#      71         r'''Run a thread if it does not exist - do nothing otherwise
#      72         '''
# ---> 73         self.tloop()
#      74         return
#      75
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tloop.py in __call__(self)
#      63     def __call__(self):
#      64         self.init()
# ---> 65         return self.eval()
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tloop_implicit.py in eval(self)
#      36             # run the iteration loop
#      37             while (k < self.k_max) and not self.user_wants_abort:
# ---> 38                 if self.tstep.R_norm < self.acc:
#      39                     if self.verbose:
#      40                         print('(%g), ' % k, end='\n')
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tstep_bc.py in _get_R_norm(self)
#     172
#     173     def _get_R_norm(self):
# --> 174         R = self.R
#     175         return np.sqrt(np.einsum('...i,...i', R, R))
#     176
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tstep_bc.py in _get_R(self)
#     178
#     179     def _get_R(self):
# --> 180         R, _, _ = self.corr_pred
#     181         return R.flatten()
#     182
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tstep_bc.py in _get_corr_pred(self)
#     121     @tr.cached_property
#     122     def _get_corr_pred(self):
# --> 123         self.K.reset_mtx()
#     124         f_Eis, K_ks, dof_Es = np.array(
#     125             [s.get_corr_pred(self.U_k, self.t_n, self.t_n1)
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tstep_bc.py in _get_K(self)
#      94     def _get_K(self):
#      95         K = SysMtxAssembly()
# ---> 96         self.bcond_mngr.setup(None)
#      97         self.bcond_mngr.register(K)
#      98         return K
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_ibvpy/ibvpy/sim/tstep_bc.py in _get_bcond_mngr(self)
#      69     @tr.cached_property
#      70     def _get_bcond_mngr(self):
# ---> 71         return BCondMngr(bcond_list=self.bc)
#      72
#      73     def init_state(self):
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_shell_analysis.py in _get_bc(self)
#      96     @tr.cached_property
#      97     def _get_bc(self):
# ---> 98         bc_fixed, _, _ = self.bc_fixed
#      99         bc_loaded, _, _ = self.bc_loaded
#     100         return bc_fixed + bc_loaded
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_shell_analysis.py in _get_bc_fixed(self)
#      83     def _get_bc_fixed(self):
#      84         xdomain, _ = self.domains[0]
# ---> 85         fixed_xyz_nodes = xdomain.bc_J_xyz
#      86         fixed_x_nodes = xdomain.bc_J_x
#      87         fixed_nodes = np.unique(np.hstack([fixed_xyz_nodes, fixed_x_nodes]))
#
# ~/miniconda3/envs/bmcs_env/lib/python3.9/site-packages/traits/has_traits.py in decorator(self)
#     925         result = self.__dict__.get(name, Undefined)
#     926         if result is Undefined:
# --> 927             self.__dict__[name] = result = function(self)
#     928
#     929         return result
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_xdomain_fe.py in _get_bc_J_xyz(self)
#     141     @tr.cached_property
#     142     def _get_bc_J_xyz(self):
# --> 143         I_M = self.I_CDij[(0, -1), :, (0, -1), :].flatten()
#     144         _, idx_remap = self.mesh.unique_node_map
#     145         J_M = idx_remap[I_M]
#
# ~/PycharmProjects/bmcs_shell/bmcs_shell/folding/wb_xdomain_fe.py in _get_I_CDij(self)
#     128     I_CDij = tr.Property
#     129     def _get_I_CDij(self):
# --> 130         return self.mesh.I_CDij
#     131
#     132     bc_J_F_xyz= tr.Property(depends_on='state_changed')
#
# AttributeError: 'NoneType' object has no attribute 'I_CDij'

# %%
import matplotlib.pylab as plt
plt.plot(*wbm.get_Pw());

# %%
15000 / 39000
# Out:
# 0.38461538461538464
