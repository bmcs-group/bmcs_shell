# %%
# %matplotlib widget
from bmcs_shell.api import WBCell5ParamPhi, WBCell4Param
import numpy as np
import sympy as sp
sp.init_printing()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
wb_cell = WBCell5ParamPhi()
wb_cell.interact()
# Out:
# C:\Users\hspartali\Anaconda3\envs\bmcs_env\lib\site-packages\traittypes\traittypes.py:97: UserWarning: Given trait value dtype "uint32" does not match required type "float32". A coerced copy has been created.
#   warnings.warn(
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %% [markdown]
# ## Solving symbolically

# %%
# 5 Params with phi

# Define coordinates
xl, yl, zl = sp.symbols('x_l y_l z_l', real=True)
xr, yr, zr = sp.symbols('x_r y_r z_r', real=True)
a, b, c, gamma, phi = sp.symbols('a b c gamma, phi', real=True, nonnegative=True)
t, t_l, t_r = sp.symbols('t, t_l, t_r', real=True)

O = sp.Matrix([0, 0, 0])
Ul_flat = sp.Matrix([-a, b, 0])
Ur_flat = sp.Matrix([a, b, 0])
Vl_flat = sp.Matrix([-c, 0, 0])
Vr_flat = sp.Matrix([c, 0, 0])

# Define vectors
Ul = sp.Matrix([xl, yl, zl])
Ur = sp.Matrix([xr, yr, zr])
Vl = sp.Matrix([-c * sp.sin(gamma), 0, c * sp.cos(gamma)])
Vr = sp.Matrix([c * sp.sin(gamma), 0, c * sp.cos(gamma)])

z = sp.Matrix([0, 0, 1])
y = sp.Matrix([0, 1, 0])
yz_plane_n = y.cross(z)
OUu_plane_n = ((Ur + Ul)/2).cross(z)

# Define unknowns
unknowns = [xl, yl, zl, xr, yr, zr]

# Define equations
eq1 = sp.simplify(Ur.norm()**2 - Ur_flat.norm()**2)
eq2 = sp.simplify(Ul.norm()**2 - Ul_flat.norm()**2)
eq3 = sp.simplify(Ul.dot(Ur) - Ul_flat.dot(Ur_flat)) # denominator was eleminated Ul.dot(Ur) / (Ul_flat.norm() * Ur_flat.norm()) as it's equal before and after folding
eq4 = sp.simplify(Ur.dot(Vr) - Ur_flat.dot(Vr_flat)) 
eq5 = sp.simplify(Ul.dot(Vl) - Ul_flat.dot(Vl_flat))
eq6 = sp.simplify(yz_plane_n.dot(OUu_plane_n)/(yz_plane_n.norm() * OUu_plane_n.norm()) - sp.cos(phi)) 

# sol = sp.solve([eq1, eq2, eq3, eq4, eq5, eq6], unknowns)
# sol

# %%
eq1, eq2, eq3, eq4, eq5, eq6
# Out:
# ⎛
# ⎜
# ⎜   2    2     2     2     2     2    2     2     2     2   2    2
# ⎜- a  - b  + xᵣ  + yᵣ  + zᵣ , - a  - b  + xₗ  + yₗ  + zₗ , a  - b  + xₗ⋅xᵣ + y
# ⎜
# ⎜
# ⎝
#
#
#
#
# ₗ⋅yᵣ + zₗ⋅zᵣ, c⋅(-a + xᵣ⋅sin(γ) + zᵣ⋅cos(γ)), c⋅(-a - xₗ⋅sin(γ) + zₗ⋅cos(γ)),
#
#
#
#
#              _________________________       ⎞
#             ╱          2            2        ⎟
# yₗ + yᵣ - ╲╱  (xₗ + xᵣ)  + (yₗ + yᵣ)  ⋅cos(φ)⎟
# ─────────────────────────────────────────────⎟
#             _________________________        ⎟
#            ╱          2            2         ⎟
#          ╲╱  (xₗ + xᵣ)  + (yₗ + yᵣ)          ⎠

# %%
eq4
# Out:
# c⋅(-a + xᵣ⋅sin(γ) + zᵣ⋅cos(γ))

# %%
zr_ = sp.solve(eq4, zr)[0]
zr_
# Out:
# a - xᵣ⋅sin(γ)
# ─────────────
#     cos(γ)

# %%
eq5
# Out:
# c⋅(-a - xₗ⋅sin(γ) + zₗ⋅cos(γ))

# %%
zl_ = sp.solve(eq5, zl)[0]
zl_
# Out:
# a + xₗ⋅sin(γ)
# ─────────────
#     cos(γ)

# %%
eq1 = eq1.subs({zr:zr_})
eq1
# Out:
#                                        2
#    2    2     2     2   (a - xᵣ⋅sin(γ))
# - a  - b  + xᵣ  + yᵣ  + ────────────────
#                                2
#                             cos (γ)

# %%
xr_sqrt_pos = True
xr_ = sp.solve(eq1, xr)
xr_ = xr_[1] if xr_sqrt_pos else xr_[0]
xr_
# Out:
#               __________
#              ╱  2     2
# a⋅sin(γ) + ╲╱  b  - yᵣ  ⋅cos(γ)

# %%
eq2 = eq2.subs({zl:zl_})
eq2
# Out:
#                                        2
#    2    2     2     2   (a + xₗ⋅sin(γ))
# - a  - b  + xₗ  + yₗ  + ────────────────
#                                2
#                             cos (γ)

# %%
xl_sqrt_pos = False
xl_ = sp.solve(eq2, xl)
xl_ = xl_[1] if xl_sqrt_pos else xl_[0]
xl_
# Out:
#                __________
#               ╱  2     2
# -a⋅sin(γ) - ╲╱  b  - yₗ  ⋅cos(γ)

# %%
eq3 = eq3.subs({zr:zr_, zl:zl_})
eq3 = eq3.subs({xr:xr_, xl:xl_})
eq3
# Out:
#                   ⎛    ⎛               __________       ⎞       ⎞ ⎛    ⎛
#                   ⎜    ⎜              ╱  2     2        ⎟       ⎟ ⎜    ⎜
#  2    2           ⎝a + ⎝-a⋅sin(γ) - ╲╱  b  - yₗ  ⋅cos(γ)⎠⋅sin(γ)⎠⋅⎝a - ⎝a⋅sin(
# a  - b  + yₗ⋅yᵣ + ────────────────────────────────────────────────────────────
#                                                                 2
#                                                              cos (γ)
#
#         __________       ⎞       ⎞
#        ╱  2     2        ⎟       ⎟   ⎛               __________       ⎞ ⎛
# γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠⋅sin(γ)⎠   ⎜              ╱  2     2        ⎟ ⎜
# ────────────────────────────────── + ⎝-a⋅sin(γ) - ╲╱  b  - yₗ  ⋅cos(γ)⎠⋅⎝a⋅sin
#
#
#
#
#          __________       ⎞
#         ╱  2     2        ⎟
# (γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠

# %%
t_l_ = sp.sqrt(b**2 - yl**2) * sp.cos(gamma)
t_r_ = sp.sqrt(b**2 - yr**2) * sp.cos(gamma)
t_ = a * sp.sin(gamma)

# %%
eq3_new = eq3.subs({t_l_: t_l, t_r_: t_r, t_: t})
eq3_new
# Out:
#  2    2           (a + (-t - tₗ)⋅sin(γ))⋅(a - (t + tᵣ)⋅sin(γ))
# a  - b  + yₗ⋅yᵣ + ──────────────────────────────────────────── + (-t - tₗ)⋅(t
#                                        2
#                                     cos (γ)
#
#
# + tᵣ)

# %%
# xl_sqrt_pos = True
yl_ = sp.solve(eq3_new, yl)[0]
yl_
# Out:
#    2                                               2    2              2
# - a  + 2⋅a⋅t⋅sin(γ) + a⋅tₗ⋅sin(γ) + a⋅tᵣ⋅sin(γ) - t ⋅sin (γ) - t⋅tₗ⋅sin (γ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                          yᵣ⋅co
#
#         2               2      ⎛   2    2    2                      ⎞    2
# t⋅tᵣ⋅sin (γ) - tₗ⋅tᵣ⋅sin (γ) + ⎝- a  + b  + t  + t⋅tₗ + t⋅tᵣ + tₗ⋅tᵣ⎠⋅cos (γ)
# ─────────────────────────────────────────────────────────────────────────────
#  2
# s (γ)

# %%
eq6 = eq6.subs({xl: xl_, xr: xr_})
eq6
# Out:
#                _______________________________________________________________
#               ╱                                                             2
#              ╱               ⎛     __________             __________       ⎞
#             ╱            2   ⎜    ╱  2     2             ╱  2     2        ⎟
# yₗ + yᵣ - ╲╱    (yₗ + yᵣ)  + ⎝- ╲╱  b  - yₗ  ⋅cos(γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠
# ──────────────────────────────────────────────────────────────────────────────
#               _______________________________________________________________
#              ╱                                                             2
#             ╱               ⎛     __________             __________       ⎞
#            ╱            2   ⎜    ╱  2     2             ╱  2     2        ⎟
#          ╲╱    (yₗ + yᵣ)  + ⎝- ╲╱  b  - yₗ  ⋅cos(γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠
#
#
#
#
#
# ⋅cos(φ)
# ───────

# %%
eq6_new = eq6.subs({t_l_: t_l, t_r_: t_r})
eq6_new
# Out:
#              __________________________
#             ╱           2            2
# yₗ + yᵣ - ╲╱  (-tₗ + tᵣ)  + (yₗ + yᵣ)  ⋅cos(φ)
# ──────────────────────────────────────────────
#            __________________________
#           ╱           2            2
#         ╲╱  (-tₗ + tᵣ)  + (yₗ + yᵣ)

# %%
sol = sp.solve([eq3_new, eq6_new], [yl, yr])
sol
# Out:
# ⎡⎛
# ⎢⎜
# ⎢⎜
# ⎢⎜
# ⎢⎜
# ⎢⎜
# ⎢⎜
# ⎢⎜────────────────────────────────────────────────────────────────────────────
# ⎢⎜       _____________________________________________________________________
# ⎢⎜      ╱
# ⎢⎜     ╱              2
# ⎢⎜    ╱      2     2⋅a     4⋅a⋅t⋅sin(γ)   2⋅a⋅tₗ⋅sin(γ)   2⋅a⋅tᵣ⋅sin(γ)      2
# ⎢⎜   ╱    2⋅a  + ─────── - ──────────── - ───────────── - ───────────── - 2⋅b
# ⎢⎜  ╱               2           2               2               2
# ⎣⎝╲╱             cos (γ)     cos (γ)         cos (γ)         cos (γ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                2                                                    2
#       2     2⋅t               2⋅t⋅tₗ             2⋅t⋅tᵣ     2     tₗ
#  - 4⋅t  + ─────── - 4⋅t⋅tₗ + ─────── - 4⋅t⋅tᵣ + ─────── - tₗ  + ─────── - 2⋅tₗ
#              2                  2                  2               2
#           cos (γ)            cos (γ)            cos (γ)         sin (φ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                 ______________________________________________
#                                ╱      2    2       2         2    2
#       2⋅tₗ⋅tᵣ   2⋅tₗ⋅tᵣ   tₗ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t
# ⋅tᵣ + ─────── - ─────── - ────────────────────────────────────────────────────
#          2         2
#       cos (γ)   sin (φ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#            2                       2                       2         2    2
# ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#     2         2    2         2    2       2         2    2                2
# ⋅sin (φ) - 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ) + 8⋅t⋅tₗ⋅sin (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#     2                2                2       2                2        2    2
# ⋅sin (φ) - 4⋅t⋅tₗ⋅sin (φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅sin (φ) + tₗ ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#                       2
#                    sin (φ)⋅cos(γ)
#
#
#
#
#
#
#                       ⎛   2    2       2
#                    √2⋅⎝- a ⋅cos (γ) - a  + 2⋅a⋅t⋅sin(γ) + a⋅tₗ⋅sin(γ) + a⋅tᵣ⋅s
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#        2        2    2        2    2        2              2       2
# (γ)⋅sin (φ) - tₗ ⋅sin (γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin (γ)⋅sin (φ) + 2⋅tₗ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#          2    2         2    2       2             2                       2
# in(γ) + b ⋅cos (γ) + 2⋅t ⋅cos (γ) - t  + 2⋅t⋅tₗ⋅cos (γ) - t⋅tₗ + 2⋅t⋅tᵣ⋅cos (γ
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#        2                 2                  2    2       2        2    2
# ⋅tᵣ⋅sin (γ) - 2⋅tₗ⋅tᵣ⋅sin (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ) - tᵣ ⋅sin (γ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                       2           ⎞
# ) - t⋅tᵣ + 2⋅tₗ⋅tᵣ⋅cos (γ) - tₗ⋅tᵣ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# __________________                                ____________________________
#   2    2        2                     2          ╱      2    2       2
# tᵣ ⋅sin (φ) + tᵣ  ⋅cos(φ)     2     tᵣ      tᵣ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅
# ───────────────────────── - tᵣ  + ─────── + ──────────────────────────────────
#                                      2
#                                   sin (φ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#  2    2                      2                       2                       2
# a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#          2    2       2         2    2         2    2       2         2    2
# (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) - 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#               2       2                2                2       2
# ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tₗ⋅sin (φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                         2
#                                      sin (φ)⋅cos(γ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#    2        2    2       2        2    2        2    2        2              2
# sin (φ) + tₗ ⋅sin (γ)⋅sin (φ) - tₗ ⋅sin (γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#        2                 2                 2                  2    2       2
# (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅sin (γ) - 2⋅tₗ⋅tᵣ⋅sin (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                 ______________
#                                                                ╱
#                                                               ╱              2
#                                                              ╱      2     2⋅a
#                                                       √2⋅   ╱    2⋅a  + ──────
#                                                            ╱               2
#                                                          ╲╱             cos (γ
# ────────────────────────────────────────────────────, ────────────────────────
# ____________________________________________
# ____________________________________
#       2    2        2    2        2
# ) - tᵣ ⋅sin (γ) - tᵣ ⋅sin (φ) + tᵣ  ⋅cos(φ)     2
# ─────────────────────────────────────────── ⋅cos (γ)
#
#
#
# ______________________________________________________________________________
#
#                                                                       2
#     4⋅a⋅t⋅sin(γ)   2⋅a⋅tₗ⋅sin(γ)   2⋅a⋅tᵣ⋅sin(γ)      2      2     2⋅t
# ─ - ──────────── - ───────────── - ───────────── - 2⋅b  - 4⋅t  + ─────── - 4⋅t
#          2               2               2                          2
# )     cos (γ)         cos (γ)         cos (γ)                    cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#
#                                              2
#        2⋅t⋅tₗ             2⋅t⋅tᵣ     2     tₗ                2⋅tₗ⋅tᵣ   2⋅tₗ⋅tᵣ
# ⋅tₗ + ─────── - 4⋅t⋅tᵣ + ─────── - tₗ  + ─────── - 2⋅tₗ⋅tᵣ + ─────── - ───────
#          2                  2               2                   2         2
#       cos (γ)            cos (γ)         sin (φ)             cos (γ)   sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#          _____________________________________________________________________
#         ╱      2    2       2         2    2                      2
#    tₗ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin (φ) - 4⋅a⋅t
#  - ───────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#             2                       2         2    2       2         2    2
# ₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) - 4⋅b ⋅sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#       2    2       2         2    2                2       2                2
#  + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tₗ⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#                                                                              2
#                                                                           sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#                2       2                2        2    2       2        2    2
# φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅sin (φ) + tₗ ⋅sin (γ)⋅sin (φ) - tₗ ⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#
# (φ)⋅cos(γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#        2    2        2              2       2                 2
# γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅sin (γ) - 2⋅tₗ⋅tᵣ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             2
#
#
#
#
#
#
#
# ______________________________________________________________________________
# _________________________________________________________________________
#   2                  2    2       2        2    2        2    2        2
# in (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ) - tᵣ ⋅sin (γ) - tᵣ ⋅sin (φ) + tᵣ  ⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#                            ___________________________________________________
#                2          ╱      2    2       2         2    2
# φ)     2     tᵣ      tᵣ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(
# ── - tᵣ  + ─────── + ─────────────────────────────────────────────────────────
#               2
#            sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#       2                       2                       2         2    2       2
# γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#          2    2         2    2       2         2    2                2       2
# (φ) - 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#                 2                2       2                2        2    2
# (φ) - 4⋅t⋅tₗ⋅sin (φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅sin (φ) + tₗ ⋅sin (γ)⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                  2
#               sin (φ)⋅cos(γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#   2        2    2        2    2        2              2       2
# in (φ) - tₗ ⋅sin (γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#   2                 2                  2    2       2        2    2        2
# in (γ) - 2⋅tₗ⋅tᵣ⋅sin (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ) - tᵣ ⋅sin (γ) - tᵣ ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# _____________________⎞  ⎛
# _____________        ⎟  ⎜
#   2        2         ⎟  ⎜
# in (φ) + tᵣ  ⋅cos(φ) ⎟  ⎜
# ──────────────────── ⎟  ⎜
#                      ⎟  ⎜
#                      ⎟  ⎜
# ─────────────────────⎟, ⎜─────────────────────────────────────────────────────
#                      ⎟  ⎜       ______________________________________________
#                      ⎟  ⎜      ╱
#                      ⎟  ⎜     ╱              2
#                      ⎟  ⎜    ╱      2     2⋅a     4⋅a⋅t⋅sin(γ)   2⋅a⋅tₗ⋅sin(γ)
#                      ⎟  ⎜   ╱    2⋅a  + ─────── - ──────────── - ─────────────
#                      ⎟  ⎜  ╱               2           2               2
#                      ⎠  ⎝╲╱             cos (γ)     cos (γ)         cos (γ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#
#                                       2
#    2⋅a⋅tᵣ⋅sin(γ)      2      2     2⋅t               2⋅t⋅tₗ             2⋅t⋅tᵣ
#  - ───────────── - 2⋅b  - 4⋅t  + ─────── - 4⋅t⋅tₗ + ─────── - 4⋅t⋅tᵣ + ───────
#          2                          2                  2                  2
#       cos (γ)                    cos (γ)            cos (γ)            cos (γ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
#                                                        _______________________
#              2                                        ╱      2    2       2
#      2     tₗ                2⋅tₗ⋅tᵣ   2⋅tₗ⋅tᵣ   tₗ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ)
#  - tₗ  + ─────── - 2⋅tₗ⋅tᵣ + ─────── - ─────── + ─────────────────────────────
#             2                   2         2
#          sin (φ)             cos (γ)   sin (φ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#       2    2                      2                       2
#  + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#     2         2    2       2         2    2         2    2       2         2
# ⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) - 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#   2                2       2                2                2       2
# in (φ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tₗ⋅sin (φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                              2
#                                           sin (φ)⋅cos(γ)
#
#
#
#
#
#
#                                              ⎛   2    2       2
#                                           √2⋅⎝- a ⋅cos (γ) - a  + 2⋅a⋅t⋅sin(γ)
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#         2        2    2       2        2    2        2    2        2
# t⋅tᵣ⋅sin (φ) + tₗ ⋅sin (γ)⋅sin (φ) - tₗ ⋅sin (γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                 2    2         2    2       2             2
#  + a⋅tₗ⋅sin(γ) + a⋅tᵣ⋅sin(γ) + b ⋅cos (γ) + 2⋅t ⋅cos (γ) - t  + 2⋅t⋅tₗ⋅cos (γ)
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#     2       2                 2                 2                  2    2
# ⋅sin (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅sin (γ) - 2⋅tₗ⋅tᵣ⋅sin (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                     2                        2           ⎞
#  - t⋅tₗ + 2⋅t⋅tᵣ⋅cos (γ) - t⋅tᵣ + 2⋅tₗ⋅tᵣ⋅cos (γ) - tₗ⋅tᵣ⎠
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# _________________________________________                                _____
#   2        2    2        2    2        2                     2          ╱
# in (φ) - tᵣ ⋅sin (γ) - tᵣ ⋅sin (φ) + tᵣ  ⋅cos(φ)     2     tᵣ      tᵣ⋅╲╱  - 4⋅
# ──────────────────────────────────────────────── - tᵣ  + ─────── - ───────────
#                                                             2
#                                                          sin (φ)
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#  2    2       2         2    2                      2                       2
# a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________________________________________________________
# ______________________________________________________________________________
#                       2         2    2       2         2    2         2    2
# φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) - 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
# ______________________________________________________________________________
#
#                                        2
#  2⋅t⋅tₗ             2⋅t⋅tᵣ     2     tₗ                2⋅tₗ⋅tᵣ   2⋅tₗ⋅tᵣ   tₗ⋅
# ─────── - 4⋅t⋅tᵣ + ─────── - tₗ  + ─────── - 2⋅tₗ⋅tᵣ + ─────── - ─────── + ───
#    2                  2               2                   2         2
# cos (γ)            cos (γ)         sin (φ)             cos (γ)   sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#    ___________________________________________________________________________
#   ╱      2    2       2         2    2                      2
# ╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin (φ) - 4⋅a⋅tₗ⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#       2                       2         2    2       2         2    2
# γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) - 4⋅b ⋅sin (φ) + 8⋅t
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
# 2    2       2         2    2                2       2                2
#  ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tₗ⋅sin (φ) + 8
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2
#                                                                     sin (φ)⋅co
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#          2       2                2        2    2       2        2    2
# ⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅sin (φ) + tₗ ⋅sin (γ)⋅sin (φ) - tₗ ⋅sin (γ) - t
# ──────────────────────────────────────────────────────────────────────────────
#
# s(γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#  2    2        2              2       2                 2                 2
# ₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅sin (γ) - 2⋅tₗ⋅tᵣ⋅sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       2
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ___________________________________________________________________
#                2    2       2        2    2        2    2        2
#  - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ) - tᵣ ⋅sin (γ) - tᵣ ⋅sin (φ) + tᵣ  ⋅cos(φ)
# ────────────────────────────────────────────────────────────────────────── - t
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
#                      _________________________________________________________
#          2          ╱      2    2       2         2    2
#  2     tᵣ      tᵣ⋅╲╱  - 4⋅a ⋅sin (γ)⋅sin (φ) + 8⋅a ⋅sin (φ) - 8⋅a⋅t⋅sin(γ)⋅sin
# ᵣ  + ─────── - ───────────────────────────────────────────────────────────────
#         2
#      sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
# 2                       2                       2         2    2       2
#  (φ) - 4⋅a⋅tₗ⋅sin(γ)⋅sin (φ) - 4⋅a⋅tᵣ⋅sin(γ)⋅sin (φ) + 4⋅b ⋅sin (γ)⋅sin (φ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#    2    2         2    2       2         2    2                2       2
# 4⋅b ⋅sin (φ) + 8⋅t ⋅sin (γ)⋅sin (φ) - 4⋅t ⋅sin (φ) + 8⋅t⋅tₗ⋅sin (γ)⋅sin (φ) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#           2                2       2                2        2    2       2
# 4⋅t⋅tₗ⋅sin (φ) + 8⋅t⋅tᵣ⋅sin (γ)⋅sin (φ) - 4⋅t⋅tᵣ⋅sin (φ) + tₗ ⋅sin (γ)⋅sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#            2
#         sin (φ)⋅cos(γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#      2    2        2    2        2              2       2                 2
#  - tₗ ⋅sin (γ) - tₗ ⋅sin (φ) + tₗ  + 6⋅tₗ⋅tᵣ⋅sin (γ)⋅sin (φ) + 2⋅tₗ⋅tᵣ⋅sin (γ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ______________________________________________________________________________
# ______________________________________________________________________________
#               2                  2    2       2        2    2        2    2
#  - 2⋅tₗ⋅tᵣ⋅sin (φ) - 2⋅tₗ⋅tᵣ + tᵣ ⋅sin (γ)⋅sin (φ) - tᵣ ⋅sin (γ) - tᵣ ⋅sin (φ)
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# _______________ ⎞⎤
# _______         ⎟⎥
#      2          ⎟⎥
#  + tᵣ  ⋅cos(φ)  ⎟⎥
# ──────────────  ⎟⎥
#                 ⎟⎥
#                 ⎟⎥
# ────────────────⎟⎥
#                 ⎟⎥
#                 ⎟⎥
#                 ⎟⎥
#                 ⎟⎥
#                 ⎟⎥
#                 ⎟⎥
#                 ⎠⎦

# %%
eq6
# Out:
#                _______________________________________________________________
#               ╱                                                             2
#              ╱               ⎛     __________             __________       ⎞
#             ╱            2   ⎜    ╱  2     2             ╱  2     2        ⎟
# yₗ + yᵣ - ╲╱    (yₗ + yᵣ)  + ⎝- ╲╱  b  - yₗ  ⋅cos(γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠
# ──────────────────────────────────────────────────────────────────────────────
#               _______________________________________________________________
#              ╱                                                             2
#             ╱               ⎛     __________             __________       ⎞
#            ╱            2   ⎜    ╱  2     2             ╱  2     2        ⎟
#          ╲╱    (yₗ + yᵣ)  + ⎝- ╲╱  b  - yₗ  ⋅cos(γ) + ╲╱  b  - yᵣ  ⋅cos(γ)⎠
#
#
#
#
#
# ⋅cos(φ)
# ───────

# %%
eq6_reduced = sp.cse(eq6, ignore=(yl, yr))
eq6 = eq6_reduced[-1][0]
eq6
# Out:
#                _______________________________________________________
#               ╱                                                     2
#              ╱               ⎛        __________         __________⎞
#             ╱            2   ⎜       ╱        2         ╱        2 ⎟
# yₗ + yᵣ - ╲╱    (yₗ + yᵣ)  + ⎝- x₀⋅╲╱  x₁ - yₗ   + x₀⋅╲╱  x₁ - yᵣ  ⎠  ⋅cos(φ)
# ─────────────────────────────────────────────────────────────────────────────
#               _______________________________________________________
#              ╱                                                     2
#             ╱               ⎛        __________         __________⎞
#            ╱            2   ⎜       ╱        2         ╱        2 ⎟
#          ╲╱    (yₗ + yᵣ)  + ⎝- x₀⋅╲╱  x₁ - yₗ   + x₀⋅╲╱  x₁ - yᵣ  ⎠

# %%
eq3_reduced = sp.cse(eq3, ignore=(yl, yr))
eq3 = eq3_reduced[-1][0]
eq3
# Out:
#                                                                      ⎛       ⎛
#                   ⎛            __________⎞ ⎛           __________⎞   ⎜       ⎜
#  2                ⎜           ╱        2 ⎟ ⎜          ╱        2 ⎟   ⎝a + x₁⋅⎝
# a  - x₀ + yₗ⋅yᵣ + ⎝-x₂ - x₃⋅╲╱  x₀ - yₗ  ⎠⋅⎝x₂ + x₃⋅╲╱  x₀ - yᵣ  ⎠ + ─────────
#
#
#
#             __________⎞⎞ ⎛       ⎛           __________⎞⎞
#            ╱        2 ⎟⎟ ⎜       ⎜          ╱        2 ⎟⎟
# -x₂ - x₃⋅╲╱  x₀ - yₗ  ⎠⎠⋅⎝a - x₁⋅⎝x₂ + x₃⋅╲╱  x₀ - yᵣ  ⎠⎠
# ─────────────────────────────────────────────────────────
#                         2
#                       x₃

# %%
eq3
# Out:
#                _______________________________________________________
#               ╱                                                     2
#              ╱               ⎛        __________         __________⎞
#             ╱            2   ⎜       ╱        2         ╱        2 ⎟
# yₗ + yᵣ - ╲╱    (yₗ + yᵣ)  + ⎝- x₀⋅╲╱  x₁ - yₗ   + x₀⋅╲╱  x₁ - yᵣ  ⎠  ⋅cos(φ)
# ─────────────────────────────────────────────────────────────────────────────
#               _______________________________________________________
#              ╱                                                     2
#             ╱               ⎛        __________         __________⎞
#            ╱            2   ⎜       ╱        2         ╱        2 ⎟
#          ╲╱    (yₗ + yᵣ)  + ⎝- x₀⋅╲╱  x₁ - yₗ   + x₀⋅╲╱  x₁ - yᵣ  ⎠

# %%
sol = sp.solve([eq3, eq6], [yl, yr])
sol
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## Solving numerically

# %%
from scipy.optimize import fsolve

# Define the values
a = 1000
b = 1000
c = 1000
gamma = np.pi/4
phi = np.pi/6


# Define a function that takes the unknowns as input and returns the equations as a numpy array
def equations(vars):
    xr, yr, zr, xl, yl, zl = vars

    z = np.array([0, 0, 1])

    Ur_flat = np.array([a, b, 0])
    Ul_flat = np.array([-a, b, 0])
    Vr_flat = np.array([c, 0, 0])
    Vl_flat = np.array([-c, 0, 0])

    Ul = np.array([xl, yl, zl])
    Ur = np.array([xr, yr, zr])
    Vl = np.array([-c * np.sin(gamma), 0, c * np.cos(gamma)])
    Vr = np.array([c * np.sin(gamma), 0, c * np.cos(gamma)])

    yz_plane_n = np.array([1, 0, 0])
    OUu_plane_n = np.cross((Ur + Ul) / 2, z)

    eq1 = np.linalg.norm(Ur) ** 2 - np.linalg.norm(Ur_flat) ** 2 # OU_ur is constant
    eq2 = np.linalg.norm(Ul) ** 2 - np.linalg.norm(Ul_flat) ** 2 # OU_ul is constant
    eq3 = np.dot(Ul, Ur) - np.dot(Ul_flat, Ur_flat) # angle (OU_ur, OU_ul) is constant
    eq4 = np.dot(Ur, Vr) - np.dot(Ur_flat, Vr_flat) # angle (OU_ur, OVr) is constant
    eq5 = np.dot(Ul, Vl) - np.dot(Ul_flat, Vl_flat) # angle (OU_ul, OVl) is constant
    # eq6: angle between plane yz and plane spanned with [0, 0, 1] with O((U_ur + U_ul)/2) is phi
    eq6 = np.dot(yz_plane_n, OUu_plane_n)/ (np.linalg.norm(yz_plane_n) * np.linalg.norm(OUu_plane_n)) - np.cos(phi)

    return np.array([eq1, eq2, eq3, eq4, eq5, eq6])

# Define initial guesses for the unknowns
x0 = np.array([a, a, a, -a, a, a])

# Call fsolve to solve the equations
sol = fsolve(equations, x0)

x_ur, y_ur, z_ur, x_ul, y_ul, z_ul = sol

if (phi > 0 and (x_ur + x_ul) / 2 < 0) or (phi < 0 and (x_ur + x_ul) / 2 > 0):
    x_ur, y_ur, z_ur, x_ul, y_ul, z_ul = -x_ul, y_ul, z_ul, -x_ur, y_ur, z_ur

# Print the solution
print('[xr,   yr,   zr, xl,   yl,   zl]')
print(x_ur, y_ur, z_ur, x_ul, y_ul, z_ul)
