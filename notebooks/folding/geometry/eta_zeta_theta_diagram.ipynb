# %% [markdown]
# # Waterbomb tessellation demo

# %%
# %matplotlib widget
from bmcs_shell.api import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from bmcs_utils.api import *
import numpy as np

# %% [markdown]
# # Analytical tessellations

# %% [markdown]
# ## Symmetric 4P waterbomb cell

# %%
a = 1000
n_eta = 20
n_zeta = 20
etas = np.linspace(0.7, 3, n_eta)   # 0.48, 1.5
zetas = np.linspace(0.2, 1, n_zeta)
thetas = np.zeros((n_zeta, n_eta))

for i_zeta, zeta in enumerate(zetas):
    for j_eta, eta in enumerate(etas):   
        wbt4p = WBTessellation4P(a = a, b=eta * a, c = zeta * a, gamma=np.pi/4)
        thetas[i_zeta, j_eta] = wbt4p.wb_cell.symb.get_theta_sol()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

etas_grid, zetas_grid = np.meshgrid(etas, zetas)

ax.plot_surface(etas_grid, zetas_grid, thetas, cmap='viridis')

contour = ax.contour(etas_grid, zetas_grid, thetas, levels=[-0.75, -0.25, 0, 0.25, 0.75], colors='black', linewidths=2)

# ax.plot(contour.allsegs[1][0][:, 0], contour.allsegs[1][0][:, 1])

# ax.invert_xaxis()
# ax.invert_yaxis()

ax.set_xlabel(r'$\eta [-]$')
ax.set_ylabel(r'$\zeta [-]$')
ax.set_zlabel(r'$\theta [\mathrm{rad}]$')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.savefig('3d_etas_zetas_thetas.svg')

# %%
etas_zetas = contour.allsegs[1][0]
etas_list = etas_zetas[:, 0]
zetas_list = etas_zetas[:, 1]
etas_zetas
# Out:
# array([[ 0.04474232,  0.00753247],
#        [ 0.04008193,  0.00764709],
#        [ 0.03411916,  0.00777582],
#        [ 0.03326386,  0.00778483],
#        [ 0.02815773,  0.00790328],
#        [ 0.02219368,  0.00802601],
#        [ 0.02182588,  0.00802843],
#        [ 0.01623016,  0.00814691],
#        [ 0.01045947,  0.00825433],
#        [ 0.01026143,  0.00826104],
#        [ 0.00429127,  0.00837184],
#        [-0.00076876,  0.0084433 ],
#        [-0.00168777,  0.00847306],
#        [-0.00767336,  0.00856693],
#        [-0.01185266,  0.00859299],
#        [-0.01367445,  0.00864616],
#        [-0.0196934 ,  0.00870919],
#        [-0.02271214,  0.00867973],
#        [-0.02574364,  0.0087454 ],
#        [-0.03184312,  0.00874092],
#        [-0.03322968,  0.00866853],
#        [-0.03802674,  0.00866859]])

# %%
wb = WBTessellation4P(gamma=np.pi/4, a=1000, b= etas_list[-1]* 1000, c=zetas_list[-1]* 1000)
wb.interact()
k3d_plot = wb.pb.plot_fig
k3d_plot.screenshot_scale = 5.5
k3d_plot.grid_visible = False
k3d_plot.camera = [16538.7608945059,
 18416.754850286212,
 6668.558949898217,
 -541.8815416486052,
 690.6947856269203,
 -2890.347115011586,
 -0.2186371159604114,
 -0.2195354464308322,
 0.9507901973016587]
# Out:
# <lambdifygenerated-2818>:2: RuntimeWarning: invalid value encountered in sqrt
#   return arcsin((-a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))*tan(gamma) + a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))/cos(gamma) + 2*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2*sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2)/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) - sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2))/(a*(-tan(gamma) + cos(gamma)**(-1.0)) + sqrt(-a**2*(-tan(gamma) + cos(gamma)**(-1.0))**2 + b**2)*(a*(-tan(gamma) + cos(gamma)**(-1.0)) + 2*a*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2*tan(gamma)/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) - 2*a*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2/((2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)*cos(gamma)) - a*tan(gamma) + a/cos(gamma) - c*cos(gamma) + 2*sqrt(-(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) + 1)*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))*sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2)/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2))/(a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))*tan(gamma) - a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))/cos(gamma) - sqrt(-a**2*(-tan(gamma) + cos(gamma)**(-1.0))**2 + b**2) - 2*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2*sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2)/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) + sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2))))
# <lambdifygenerated-2817>:2: RuntimeWarning: invalid value encountered in sqrt
#   return a*(-tan(gamma) + cos(gamma)**(-1.0)) + sqrt(-a**2*(-tan(gamma) + cos(gamma)**(-1.0))**2 + b**2)*(a*(-tan(gamma) + cos(gamma)**(-1.0)) + 2*a*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2*tan(gamma)/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) - 2*a*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2/((2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)*cos(gamma)) - a*tan(gamma) + a/cos(gamma) - c*cos(gamma) + 2*sqrt(-(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) + 1)*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))*sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2)/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2))/(a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))*tan(gamma) - a*sin(2*arcsin((a*tan(gamma) - a/cos(gamma) + c*cos(gamma))/sqrt(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2)))/cos(gamma) - sqrt(-a**2*(-tan(gamma) + cos(gamma)**(-1.0))**2 + b**2) - 2*(a*tan(gamma) - a/cos(gamma) + c*cos(gamma))**2*sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2)/(2*a*c*sin(gamma) - 2*a*c + b**2 + c**2*cos(gamma)**2) + sqrt(2*a**2*sin(gamma)/cos(gamma)**2 + a**2 - 2*a**2/cos(gamma)**2 + b**2))
# <lambdifygenerated-2815>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(-a**2*(-tan(gamma) + cos(gamma)**(-1.0))**2 + b**2)
# /Users/gui/Documents/bmcs_folder/bmcs_virtual/lib/python3.12/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "uint32" does not match required type "float32". A coerced copy has been created.
#   warnings.warn(
# Output()
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border_bottom='solid 1p…
# Output()
# Output()
# Output()

# %%
fig_pattern, _ = wb.plot_folding_pattern()
fig_pattern.savefig('fig.svg')
# Out:
# Plot tessellation with gamma= 89.99 °
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Semi-symmetric 5P cell (beta)

# %%
wbttpv2 = WBTessellation5PBeta(wb_cell_=WBCell5ParamBeta(gamma = 0.9, beta_1= 0), sol_num=4)
wbttpv2.interact()

# Quick fix to activate interactivity 
wbttpv2.wb_cell_.callback_fun = wbttpv2.update_plot_
# Out:
# W: 11358024691.35831
# T_rho: 56790124.375576705
# T_sigma: 56790122.53800375
# sol_P2_t_2: 0.5649397553698526
# sol_Q2_u_2: 0.564939903014138
# Ana. solution: [-1.02848197 -1.02848175]
# Output()
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border_bottom='solid 1p…
