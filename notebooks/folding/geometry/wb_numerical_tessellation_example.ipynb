# %% [markdown]
# # Numerical tessellation of waterbomb cells

# %% [markdown]
# This NumericalTessellation technique will work with any waterbomb cell with 6 facets and following enumeration of the vertices indices.
# ![image.png](attachment:image.png)

# %%
# %matplotlib widget
from bmcs_shell.api import WBElem5Param, WBElemSymb5ParamXL, WBNumericalTessellation
import numpy as np

# %%
# data = dict(gamma=0.2, x_ur=1400, a=1000, b=1700, c=850, show_wireframe=True)
data = dict(gamma=0.2, a=1000, b=1700, c=850, show_wireframe=True)
WBNumericalTessellation(**data).interact()
# Out:
# smallest_dist= 43.98467174704884
# ...
# smallest_dist= 33.88187404192703
# smallest_dist= 24.433681702485977
# smallest_dist= 15.98752481500355
# smallest_dist= 8.901387249502541
# smallest_dist= 3.549845680900436
# smallest_dist= 0.34161188528683467
# smallest_dist= 0.0013333687053624494
# smallest_dist= 2.2899057621546977
# smallest_dist= 8.693942817562817
# smallest_dist= 19.948848620769553
# smallest_dist= 37.79926310036105
# smallest_dist= 67.43263572410035
# Error while minimizing!
# d:\homam\synced\programming\python\bmcs_shell\bmcs_shell\folding\geometry\wb_cell_5p_v2.py:55: RuntimeWarning: invalid value encountered in sqrt
#   sin_psi5 = sqrt(b ** 2 + 2 * a * sqrt(a ** 2 + b ** 2) * cos(beta) * cos(2 * gamma) - (a ** 2 + b ** 2) * (
# d:\homam\synced\programming\python\bmcs_shell\bmcs_shell\folding\geometry\wb_cell_5p_v2.py:59: RuntimeWarning: invalid value encountered in sqrt
# ...
