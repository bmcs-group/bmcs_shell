# %% [markdown]
# # Numerical tessellation of waterbomb cells

# %% [markdown]
# This NumericalTessellation technique will work with any waterbomb cell with 6 facets and following enumeration of the vertices indices.
# ![image.png](attachment:image.png)

# %%
# %matplotlib widget
from bmcs_shell.api import WBCell, WBElem5Param, WBElem5ParamV2, WBElemSymb5ParamXL, WBNumericalTessellation, WB5PTessellationTesting, WB5PTessellation, WBElem4Param
import numpy as np

# %%
# data = dict(gamma=0.2, x_ur=1400, a=1000, b=1700, c=850, show_wireframe=True)
# data = dict(gamma=0.2, a=1000, b=1700, c=850, show_wireframe=True)
data = dict(a = 500, b = 750, c = 400, gamma = 0.9, beta= 1.78, show_wireframe=True)

# wb = WBElem5Param(**data)
# wbnt = WBNumericalTessellation(wb_cell = wb)

wbnt = WBNumericalTessellation()
wbnt.interact()
# Out:
# smallest_dist= 0.0038298009845793967
# ...

# %%
WBElem4Param().interact()

# %%
data = dict(a = 500, b = 750, c = 400, gamma = 0.9, beta= 1.78, n_x=8, n_y=6, calc_analytically = True, show_wireframe=True)
wbnt = WB5PTessellation(**data)
wbnt.interact()

# %%
data = dict(a = 500, b = 750, c = 400, gamma = 0.9, beta= 1.78, n_x=5, n_y=5, calc_analytically = True, show_wireframe=True)
wbnt = WB5PTessellationTesting(**data)
wbnt.interact()
# Out:
# ---------------------------
# smallest_dist= 1.8688989763984735e-05
# num_sol= [-1.7754742  -1.49767877]
# original sigmas= [2.41617566 1.34924866 2.84240021 1.7754732 ]
# original rhos= [2.693971   1.06053265 3.13111622 1.49767787]
# sigmas= [2.41617566 1.34924866 2.84240021 1.7754732 ]
# rhos= [2.693971   1.06053265 3.13111622 1.49767787]
# Solution 2 was picked (nearst to numerical sol), diff=5.682934283242149
# ...
